# %%
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from scipy.stats import t
import math

def rbf_kernel(X1, X2, lengthscale=1.0, variance=1.0):
    """
    Computes the RBF kernel matrix between two sets of points.
    """
    # Ensure lengthscale and variance are tensors for autograd
    lengthscale = torch.as_tensor(lengthscale, dtype=X1.dtype, device=X1.device)
    variance = torch.as_tensor(variance, dtype=X1.dtype, device=X1.device)
    
    sqdist = torch.cdist(X1, X2, p=2).pow(2)
    return variance * torch.exp(-0.5 * sqdist / lengthscale**2)

class TPRegression:
    """
    Implementation of Variational EM for Student-t Process Regression.
    - E-Step: CAVI updates for variational parameters.
    - M-Step: Gradient-based optimization of model hyperparameters and inducing points.
    """
    def __init__(self, X, y, Z_initial, nu_f=5.0, nu_e=5.0, kernel_lengthscale=1.0, kernel_variance=1.0, likelihood_sigma=1.0):
        self.X = X
        self.y = y.squeeze()
        self.N, self.D = X.shape
        self.M = Z_initial.shape[0]

        # --- Initialize Hyperparameters and Inducing Points (M-step) ---
        # These are now learnable parameters. We optimize their log for stability.
        self.log_nu_f = torch.nn.Parameter(torch.log(torch.tensor(nu_f)))
        self.log_nu_epsilon = torch.nn.Parameter(torch.log(torch.tensor(nu_e)))
        self.log_sigma_sq = torch.nn.Parameter(torch.log(torch.tensor(likelihood_sigma**2)))
        self.log_kernel_lengthscale = torch.nn.Parameter(torch.log(torch.tensor(kernel_lengthscale)))
        self.log_kernel_variance = torch.nn.Parameter(torch.log(torch.tensor(kernel_variance)))
        self.Z = torch.nn.Parameter(Z_initial.clone())

        # --- Initialize Variational Parameters (E-step) ---
        self.m_u = torch.zeros(self.M, 1)
        self.S_u = torch.eye(self.M)
        self.alpha_r = torch.tensor(1.0)
        self.beta_r = torch.tensor(1.0)
        self.alpha_lambda = torch.ones(self.N)
        self.beta_lambda = torch.ones(self.N)
        
    def _get_hyperparams(self):
        """Returns the exponentiated (positive) hyperparameters."""
        return {
            "nu_f": torch.exp(self.log_nu_f),
            "nu_epsilon": torch.exp(self.log_nu_epsilon),
            "sigma_sq": torch.exp(self.log_sigma_sq),
            "lengthscale": torch.exp(self.log_kernel_lengthscale),
            "variance": torch.exp(self.log_kernel_variance)
        }
        
    def _e_step(self, cavi_max_iter=1):
        """Performs the CAVI updates for the variational parameters (E-Step)."""
        with torch.no_grad(): # No gradients needed for the E-step updates
            params = self._get_hyperparams()
            K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
            K_ZZ_inv = torch.inverse(K_ZZ)
            K_XZ = rbf_kernel(self.X, self.Z, params['lengthscale'], params['variance'])
            
            for _ in range(cavi_max_iter):
                # Update q(lambda)
                K_ZZ_inv_m_u = torch.linalg.solve(K_ZZ, self.m_u)
                expected_f_mean = K_XZ @ K_ZZ_inv_m_u
                if self.alpha_r > 1: expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
                else: expected_r_inv = self.beta_r
                k_ii = torch.diag(rbf_kernel(self.X, self.X, params['lengthscale'], params['variance']))
                K_XZ_K_ZZ_inv = K_XZ @ K_ZZ_inv
                var_f_term1 = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * K_XZ).sum(dim=1))
                var_f_term2 = (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
                var_f = var_f_term1 + var_f_term2
                expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f
                self.alpha_lambda = params['nu_epsilon'] / 2.0 + 0.5
                self.beta_lambda = params['nu_epsilon'] / 2.0 + (0.5 / params['sigma_sq']) * expected_sq_error

                # Update q(r)
                trace_term = torch.trace(K_ZZ_inv @ self.S_u)
                mean_term = self.m_u.T @ K_ZZ_inv @ self.m_u
                expected_u_quadratic_form = trace_term + mean_term
                self.alpha_r = params['nu_f'] / 2.0 + self.M / 2.0
                self.beta_r = params['nu_f'] / 2.0 + 0.5 * expected_u_quadratic_form.squeeze()

                # Update q(u)
                expected_r = self.alpha_r / self.beta_r
                expected_lambda = self.alpha_lambda / self.beta_lambda
                precision_u_prior = expected_r * K_ZZ_inv
                K_ZX = K_XZ.T
                A = K_ZX * (expected_lambda / params['sigma_sq'])
                B = A @ K_XZ
                precision_u_lik = K_ZZ_inv.T @ B @ K_ZZ_inv
                precision_u = precision_u_prior + precision_u_lik
                self.S_u = torch.inverse(precision_u + torch.eye(self.M) * 1e-6)
                b = K_ZZ_inv.T @ (K_ZX @ (expected_lambda * self.y / params['sigma_sq']))
                self.m_u = (self.S_u @ b).unsqueeze(1)

    def _calculate_elbo(self):
        """Calculates the Evidence Lower Bound (ELBO) for the M-step."""
        params = self._get_hyperparams()
        
        K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
        K_ZZ_inv = torch.inverse(K_ZZ)
        K_XZ = rbf_kernel(self.X, self.Z, params['lengthscale'], params['variance'])
        k_ii = torch.diag(rbf_kernel(self.X, self.X, params['lengthscale'], params['variance']))

        # 1. Expected Log-Likelihood
        expected_log_lambda = torch.digamma(self.alpha_lambda) - torch.log(self.beta_lambda)
        expected_lambda = self.alpha_lambda / self.beta_lambda
        K_ZZ_inv_m_u = torch.linalg.solve(K_ZZ, self.m_u)
        expected_f_mean = K_XZ @ K_ZZ_inv_m_u
        if self.alpha_r > 1: expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
        else: expected_r_inv = self.beta_r
        K_XZ_K_ZZ_inv = K_XZ @ K_ZZ_inv
        var_f = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * K_XZ).sum(dim=1)) + \
                (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
        expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f
        
        log_lik = 0.5 * torch.sum(expected_log_lambda - math.log(2 * math.pi) - torch.log(params['sigma_sq']) - \
                                  expected_lambda / params['sigma_sq'] * expected_sq_error)

        # 2. KL Divergences
        p_alpha_r, p_beta_r = params['nu_f'] / 2.0, params['nu_f'] / 2.0
        kl_r = (self.alpha_r - p_alpha_r) * torch.digamma(self.alpha_r) - torch.lgamma(self.alpha_r) + torch.lgamma(p_alpha_r) + \
               p_alpha_r * (torch.log(self.beta_r) - torch.log(p_beta_r)) + self.alpha_r * (p_beta_r - self.beta_r) / self.beta_r
        
        expected_log_r = torch.digamma(self.alpha_r) - torch.log(self.beta_r)
        kl_u = 0.5 * (
            -torch.logdet(self.S_u) - self.M * expected_log_r + torch.logdet(K_ZZ) + \
            (self.alpha_r / self.beta_r) * (torch.trace(K_ZZ_inv @ self.S_u) + self.m_u.T @ K_ZZ_inv @ self.m_u) - self.M
        ).squeeze()
        
        # CORRECTED a typo here: params['nu_e'] -> params['nu_epsilon']
        p_alpha_lambda, p_beta_lambda = params['nu_epsilon'] / 2.0, params['nu_epsilon'] / 2.0
        kl_lambda = torch.sum((self.alpha_lambda - p_alpha_lambda) * torch.digamma(self.alpha_lambda) - \
                    torch.lgamma(self.alpha_lambda) + torch.lgamma(p_alpha_lambda) + \
                    p_alpha_lambda * (torch.log(self.beta_lambda) - torch.log(p_beta_lambda)) + \
                    self.alpha_lambda * (p_beta_lambda - self.beta_lambda) / self.beta_lambda)

        return log_lik - kl_u - kl_r - kl_lambda

    def _m_step(self, optimizer):
        """Performs the gradient update for the hyperparameters (M-Step)."""
        optimizer.zero_grad()
        elbo = self._calculate_elbo()
        loss = -elbo # Maximize ELBO by minimizing -ELBO
        loss.backward()
        optimizer.step()
        return elbo.item()

    def fit(self, max_iter_global=100, cavi_max_iter=10, lr=0.01):
        """Runs the full Variational EM algorithm."""
        optimizer = optim.Adam(
            [self.log_nu_f, self.log_nu_epsilon, self.log_sigma_sq,
             self.log_kernel_lengthscale, self.log_kernel_variance, self.Z],
            lr=lr
        )
        
        elbo_history = []
        print("Starting Variational EM optimization...")
        for i in range(max_iter_global):
            self._e_step(cavi_max_iter=cavi_max_iter)
            elbo = self._m_step(optimizer)
            elbo_history.append(elbo)
            
            if (i + 1) % 50 == 0:
                print(f"EM Iteration {i+1}/{max_iter_global}, ELBO: {elbo:.4f}")
        
        print("\nOptimization finished.")
        return elbo_history

    def predict(self, X_test):
        """
        Makes predictions for new data X_test.
        Returns the parameters of the predictive Student-t distribution.
        """
        with torch.no_grad():
            params = self._get_hyperparams()
            
            K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
            K_ZZ_inv = torch.inverse(K_ZZ)
            K_star_Z = rbf_kernel(X_test, self.Z, params['lengthscale'], params['variance'])
            k_star_star = torch.diag(rbf_kernel(X_test, X_test, params['lengthscale'], params['variance']))

            K_ZZ_inv_m_u = torch.linalg.solve(K_ZZ, self.m_u)
            pred_mean = (K_star_Z @ K_ZZ_inv_m_u).squeeze()

            K_star_Z_K_ZZ_inv = K_star_Z @ K_ZZ_inv
            gp_var = k_star_star - (K_star_Z_K_ZZ_inv * K_star_Z).sum(dim=1) + \
                     (K_star_Z_K_ZZ_inv @ self.S_u * K_star_Z_K_ZZ_inv).sum(dim=1)
            
            pred_nu = 2 * self.alpha_r
            pred_scale_sq = gp_var * (self.beta_r / self.alpha_r)
            
            return pred_mean, pred_scale_sq, pred_nu

if __name__ == '__main__':
    # 1. Generate data
    N = 100
    X_train = torch.linspace(-5, 5, N).unsqueeze(1)
    y_true = torch.sin(X_train) * 2
    noise = torch.randn(N, 1) * 0.1
    t_dist_sample = torch.distributions.StudentT(df=2)
    outlier_noise = t_dist_sample.sample((N, 1)) * 0.5
    y_train = y_true + noise
    outlier_indices = torch.randperm(N)[:10]
    y_train[outlier_indices] += outlier_noise[outlier_indices] * 3
    y_train[30] = -4.0
    y_train[70] = 5.0

    # 2. Setup the model with INITIAL inducing points
    M = 20
    Z_initial = torch.linspace(-5, 5, M).unsqueeze(1)

    model = TPRegression(
        X=X_train,
        y=y_train,
        Z_initial=Z_initial,
        nu_f=5.0,
        nu_e=5.0,
        kernel_lengthscale=0.5,
        kernel_variance=2.0,
        likelihood_sigma=0.5
    )

    # 3. Fit the model and get ELBO history
    elbo_history = model.fit(max_iter_global=500, cavi_max_iter=5, lr=0.01)

    # Print final Z locations
    print("\n--- Initial Z ---")
    print(Z_initial.squeeze().numpy())
    print("\n--- Optimized Z ---")
    print(model.Z.detach().squeeze().numpy())
    print("-------------------")

    # 4. Make predictions
    X_test = torch.linspace(-6, 6, 200).unsqueeze(1)
    pred_mean, pred_var, pred_nu = model.predict(X_test)

    # 5. Visualize the regression results
    plt.figure(figsize=(12, 8))

    pred_scale = torch.sqrt(pred_var.clamp(min=1e-9))
    df = pred_nu.item()
    lower_quantile = t.ppf(0.025, df=df)
    upper_quantile = t.ppf(0.975, df=df)
    lower = pred_mean + lower_quantile * pred_scale
    upper = pred_mean + upper_quantile * pred_scale

    plt.fill_between(X_test.squeeze(), lower.squeeze(), upper.squeeze(), color='orange', alpha=0.3, label='95% Predictive Interval (Student-t)')
    plt.plot(X_test, pred_mean, 'r-', lw=2, label='Predictive Mean')
    plt.plot(X_train, y_train, 'kx', mew=2, label='Training Data (with outliers)')
    plt.plot(model.Z.detach(), torch.full_like(model.Z.detach(), -5.5), 'r|', ms=20, mew=2, label='Optimized Inducing Points')

    plt.title('Sparse TP Regression (with Z and Hyperparameter Optimization)', fontsize=16)
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.xlim(-6, 6)
    plt.ylim(-6, 6)
    
    # 6. Visualize ELBO history
    plt.figure(figsize=(12, 6))
    plt.plot(range(1, len(elbo_history) + 1), elbo_history, marker='.', linestyle='-')
    plt.title('Sparse TP ELBO Convergence', fontsize=16)
    plt.xlabel('Iteration', fontsize=12)
    plt.ylabel('ELBO', fontsize=12)
    plt.grid(True)
    plt.tight_layout()

    plt.show()
# Out:
# Starting Variational EM optimization...
# EM Iteration 50/500, ELBO: -83.5514
# EM Iteration 100/500, ELBO: -70.1552
# EM Iteration 150/500, ELBO: nan
# EM Iteration 200/500, ELBO: nan
# EM Iteration 250/500, ELBO: nan
# EM Iteration 300/500, ELBO: nan
# EM Iteration 350/500, ELBO: nan
# EM Iteration 400/500, ELBO: nan
# EM Iteration 450/500, ELBO: nan
# EM Iteration 500/500, ELBO: nan
#
# Optimization finished.
#
# --- Initial Z ---
# [-5.         -4.4736843  -3.9473684  -3.4210525  -2.8947368  -2.368421
#  -1.8421052  -1.3157893  -0.78947353 -0.26315773  0.26315773  0.78947353
#   1.3157893   1.8421052   2.368421    2.8947368   3.4210525   3.9473684
#   4.4736843   5.        ]
#
# --- Optimized Z ---
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
# -------------------

# %%
import torch
import torch.optim as optim

# A placeholder for a kernel function (e.g., RBF)
def rbf_kernel(X1, X2, lengthscale=1.0, variance=1.0):
    """
    Computes the RBF kernel matrix between two sets of points.
    """
    sqdist = torch.cdist(X1, X2, p=2).pow(2)
    return variance * torch.exp(-0.5 * sqdist / lengthscale**2)

class TPRegressionVariationalEM:
    """
    Implementation of Variational EM for Student-t Process Regression.
    - E-Step: CAVI updates for variational parameters.
    - M-Step: Gradient-based optimization of model hyperparameters.
    """
    def __init__(self, X, y, M=20):
        self.X = X
        self.y = y.squeeze()
        self.N, self.D = X.shape
        self.M = M

        # --- Initialize Hyperparameters to be Optimized (M-step) ---
        # These are now learnable parameters.
        self.log_nu_f = torch.nn.Parameter(torch.log(torch.tensor(5.0)))
        self.log_nu_epsilon = torch.nn.Parameter(torch.log(torch.tensor(5.0)))
        self.log_sigma_sq = torch.nn.Parameter(torch.log(torch.tensor(1.0)))
        self.log_kernel_lengthscale = torch.nn.Parameter(torch.tensor(0.0))
        self.log_kernel_variance = torch.nn.Parameter(torch.tensor(0.0))

        # --- Initialize Variational Parameters (E-step) ---
        indices = torch.randperm(self.N)[:self.M]
        self.Z = self.X[indices].clone()

        self.m_u = torch.zeros(self.M, 1)
        self.S_u = torch.eye(self.M)
        self.alpha_r = torch.tensor(1.0)
        self.beta_r = torch.tensor(1.0)
        self.alpha_lambda = torch.ones(self.N)
        self.beta_lambda = torch.ones(self.N)
        
        # Optimizer for the M-step
        self.optimizer = optim.Adam(
            [self.log_nu_f, self.log_nu_epsilon, self.log_sigma_sq,
             self.log_kernel_lengthscale, self.log_kernel_variance],
            lr=0.01
        )

    def _get_hyperparams(self):
        """Returns the exponentiated (positive) hyperparameters."""
        return {
            "nu_f": torch.exp(self.log_nu_f),
            "nu_epsilon": torch.exp(self.log_nu_epsilon),
            "sigma_sq": torch.exp(self.log_sigma_sq),
            "lengthscale": torch.exp(self.log_kernel_lengthscale),
            "variance": torch.exp(self.log_kernel_variance)
        }
        
    def _e_step(self, cavi_iterations=10):
        """Performs the CAVI updates for the variational parameters (E-Step)."""
        with torch.no_grad(): # No gradients needed for the E-step updates
            params = self._get_hyperparams()
            K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
            K_ZZ_inv = torch.inverse(K_ZZ)
            K_XZ = rbf_kernel(self.X, self.Z, params['lengthscale'], params['variance'])
            
            for _ in range(cavi_iterations):
                # Update q(lambda)
                K_ZZ_inv_m_u = torch.linalg.solve(K_ZZ, self.m_u)
                expected_f_mean = K_XZ @ K_ZZ_inv_m_u
                if self.alpha_r > 1: expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
                else: expected_r_inv = self.beta_r
                k_ii = torch.diag(rbf_kernel(self.X, self.X, params['lengthscale'], params['variance']))
                K_XZ_K_ZZ_inv = K_XZ @ K_ZZ_inv
                var_f_term1 = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * K_XZ).sum(dim=1))
                var_f_term2 = (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
                var_f = var_f_term1 + var_f_term2
                expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f
                self.alpha_lambda = params['nu_epsilon'] / 2.0 + 0.5
                self.beta_lambda = params['nu_epsilon'] / 2.0 + (0.5 / params['sigma_sq']) * expected_sq_error

                # Update q(r)
                trace_term = torch.trace(K_ZZ_inv @ self.S_u)
                mean_term = self.m_u.T @ K_ZZ_inv @ self.m_u
                expected_u_quadratic_form = trace_term + mean_term
                self.alpha_r = params['nu_f'] / 2.0 + self.M / 2.0
                self.beta_r = params['nu_f'] / 2.0 + 0.5 * expected_u_quadratic_form.squeeze()

                # Update q(u)
                expected_r = self.alpha_r / self.beta_r
                expected_lambda = self.alpha_lambda / self.beta_lambda
                precision_u_prior = expected_r * K_ZZ_inv
                K_ZX = K_XZ.T
                A = K_ZX * (params['sigma_sq'] * expected_lambda)
                B = A @ K_XZ
                precision_u_lik = K_ZZ_inv.T @ B @ K_ZZ_inv
                precision_u = precision_u_prior + precision_u_lik
                self.S_u = torch.inverse(precision_u + torch.eye(self.M) * 1e-6)
                b = K_ZZ_inv.T @ (K_ZX @ (params['sigma_sq'] * expected_lambda * self.y))
                self.m_u = (self.S_u @ b).unsqueeze(1)

    def _calculate_elbo(self):
        """
        Calculates the Evidence Lower Bound (ELBO)[cite: 194].
        This is required for the M-step.
        """
        params = self._get_hyperparams()
        
        # Kernel matrices needed for ELBO
        K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
        K_ZZ_inv = torch.inverse(K_ZZ)
        K_XZ = rbf_kernel(self.X, self.Z, params['lengthscale'], params['variance'])
        k_ii = torch.diag(rbf_kernel(self.X, self.X, params['lengthscale'], params['variance']))

        # 1. Expected Log-Likelihood term: E[log p(y|f, {lambda_i})] [cite: 190]
        # E[log N(y_i|f_i, (sigma^2*lambda_i)^-1)]
        expected_log_lambda = torch.digamma(self.alpha_lambda) - torch.log(self.beta_lambda)
        expected_lambda = self.alpha_lambda / self.beta_lambda
        
        K_ZZ_inv_m_u = torch.linalg.solve(K_ZZ, self.m_u)
        expected_f_mean = K_XZ @ K_ZZ_inv_m_u
        if self.alpha_r > 1: expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
        else: expected_r_inv = self.beta_r
        K_XZ_K_ZZ_inv = K_XZ @ K_ZZ_inv
        var_f_term1 = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * K_XZ).sum(dim=1))
        var_f_term2 = (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
        var_f = var_f_term1 + var_f_term2
        expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f
        
        expected_log_lik = 0.5 * torch.sum(expected_log_lambda - torch.log(2 * torch.pi * params['sigma_sq']) - expected_lambda / params['sigma_sq'] * expected_sq_error)

        # 2. KL Divergence terms [cite: 191, 192]
        # KL(q(r)||p(r))
        p_alpha_r, p_beta_r = params['nu_f'] / 2.0, params['nu_f'] / 2.0
        kl_r = (self.alpha_r - p_alpha_r) * torch.digamma(self.alpha_r) - torch.lgamma(self.alpha_r) + torch.lgamma(p_alpha_r) \
               + p_alpha_r * (torch.log(self.beta_r) - torch.log(p_beta_r)) + self.alpha_r * (p_beta_r - self.beta_r) / self.beta_r
        
        # KL(q(u)||p(u|r)) averaged over q(r)
        # We use E_q[log q(u) - log p(u|r)]
        log_det_S_u = torch.logdet(self.S_u)
        expected_log_r = torch.digamma(self.alpha_r) - torch.log(self.beta_r)
        expected_r = self.alpha_r / self.beta_r
        
        kl_u_term1 = 0.5 * (-log_det_S_u - self.M * expected_log_r + torch.logdet(K_ZZ))
        kl_u_term2 = 0.5 * expected_r * (torch.trace(K_ZZ_inv @ self.S_u) + self.m_u.T @ K_ZZ_inv @ self.m_u)
        kl_u = kl_u_term1 + kl_u_term2.squeeze() - 0.5 * self.M
        
        kl_u_r = kl_u + kl_r
        
        # KL(q(lambda_i)||p(lambda_i))
        p_alpha_lambda, p_beta_lambda = params['nu_epsilon'] / 2.0, params['nu_epsilon'] / 2.0
        kl_lambda = torch.sum((self.alpha_lambda - p_alpha_lambda) * torch.digamma(self.alpha_lambda) \
                    - torch.lgamma(self.alpha_lambda) + torch.lgamma(p_alpha_lambda) \
                    + p_alpha_lambda * (torch.log(self.beta_lambda) - torch.log(p_beta_lambda)) \
                    + self.alpha_lambda * (p_beta_lambda - self.beta_lambda) / self.beta_lambda)

        elbo = expected_log_lik - kl_u_r - kl_lambda
        return elbo

    def _m_step(self, iterations=10):
        """Performs the gradient update for the hyperparameters (M-Step)."""
        self.optimizer.zero_grad()

        for _ in range(iterations):
            elbo = self._calculate_elbo()
            loss = -elbo # We maximize ELBO, so we minimize -ELBO
            loss.backward()
            self.optimizer.step()
        return elbo.item()

    def fit(self, em_iterations=50, cavi_per_step=10):
        """
        Runs the full Variational EM algorithm.
        """
        print("Starting Variational EM optimization...")
        for i in range(em_iterations):
            # E-Step: Update variational parameters
            self._e_step(cavi_iterations=cavi_per_step)
            
            # M-Step: Update hyperparameters
            elbo = self._m_step()
            
            print(f"EM Iteration {i+1}/{em_iterations}, ELBO: {elbo:.4f}")
        
        print("\nOptimization finished.")
        final_params = self._get_hyperparams()
        print("Final Hyperparameters:")
        for name, val in final_params.items():
            print(f"  {name}: {val.item():.4f}")


if __name__ == '__main__':
    import matplotlib.pyplot as plt

    # 1. Generate data
    N = 100
    X_train = torch.linspace(-5, 5, N).unsqueeze(1)
    y_true = torch.sin(X_train) * 2
    noise = torch.randn(N, 1) * 0.1
    t_dist_sample = torch.distributions.StudentT(df=2)
    outlier_noise = t_dist_sample.sample((N, 1)) * 0.5
    y_train = y_true + noise
    outlier_indices = torch.randperm(N)[:10]
    y_train[outlier_indices] += outlier_noise[outlier_indices] * 3
    y_train[30] = -4.0
    y_train[70] = 5.0


    model = TPRegressionVariationalEM(X_train, y_train, M=20)
    model.fit(em_iterations=2000, cavi_per_step=5)
# Out:
# Starting Variational EM optimization...
# EM Iteration 1/2000, ELBO: nan
# EM Iteration 2/2000, ELBO: nan
# EM Iteration 3/2000, ELBO: nan
# EM Iteration 4/2000, ELBO: -179.7200
# EM Iteration 5/2000, ELBO: nan
# EM Iteration 6/2000, ELBO: -159.4106
# EM Iteration 7/2000, ELBO: nan
# EM Iteration 8/2000, ELBO: nan
# EM Iteration 9/2000, ELBO: nan
# EM Iteration 10/2000, ELBO: nan
# EM Iteration 11/2000, ELBO: nan
# EM Iteration 12/2000, ELBO: nan
# EM Iteration 13/2000, ELBO: nan
# EM Iteration 14/2000, ELBO: nan
# EM Iteration 15/2000, ELBO: nan
# EM Iteration 16/2000, ELBO: nan
# EM Iteration 17/2000, ELBO: nan
# EM Iteration 18/2000, ELBO: nan
# EM Iteration 19/2000, ELBO: nan
# EM Iteration 20/2000, ELBO: nan
# EM Iteration 21/2000, ELBO: nan
# EM Iteration 22/2000, ELBO: nan
# EM Iteration 23/2000, ELBO: nan
# EM Iteration 24/2000, ELBO: nan
# EM Iteration 25/2000, ELBO: nan
# EM Iteration 26/2000, ELBO: nan
# EM Iteration 27/2000, ELBO: nan
# EM Iteration 28/2000, ELBO: nan
# EM Iteration 29/2000, ELBO: nan
# EM Iteration 30/2000, ELBO: nan
# EM Iteration 31/2000, ELBO: nan
# EM Iteration 32/2000, ELBO: nan
# EM Iteration 33/2000, ELBO: nan
# EM Iteration 34/2000, ELBO: nan
# EM Iteration 35/2000, ELBO: nan
# EM Iteration 36/2000, ELBO: nan
# EM Iteration 37/2000, ELBO: nan
# EM Iteration 38/2000, ELBO: nan
# EM Iteration 39/2000, ELBO: nan
# EM Iteration 40/2000, ELBO: nan
# EM Iteration 41/2000, ELBO: nan
# EM Iteration 42/2000, ELBO: nan
# EM Iteration 43/2000, ELBO: nan
# EM Iteration 44/2000, ELBO: nan
# EM Iteration 45/2000, ELBO: nan
# EM Iteration 46/2000, ELBO: nan
# EM Iteration 47/2000, ELBO: nan
# EM Iteration 48/2000, ELBO: nan
# EM Iteration 49/2000, ELBO: nan
# EM Iteration 50/2000, ELBO: nan
# EM Iteration 51/2000, ELBO: nan
# EM Iteration 52/2000, ELBO: nan
# EM Iteration 53/2000, ELBO: nan
# EM Iteration 54/2000, ELBO: nan
# EM Iteration 55/2000, ELBO: nan
# EM Iteration 56/2000, ELBO: nan
# EM Iteration 57/2000, ELBO: nan
# EM Iteration 58/2000, ELBO: nan
# EM Iteration 59/2000, ELBO: nan
# EM Iteration 60/2000, ELBO: nan
# EM Iteration 61/2000, ELBO: nan
# EM Iteration 62/2000, ELBO: nan
# EM Iteration 63/2000, ELBO: nan
# EM Iteration 64/2000, ELBO: nan
# EM Iteration 65/2000, ELBO: nan
# EM Iteration 66/2000, ELBO: nan
# EM Iteration 67/2000, ELBO: nan
# EM Iteration 68/2000, ELBO: nan
# EM Iteration 69/2000, ELBO: nan
# EM Iteration 70/2000, ELBO: nan
# EM Iteration 71/2000, ELBO: nan
# EM Iteration 72/2000, ELBO: nan
# EM Iteration 73/2000, ELBO: nan
# EM Iteration 74/2000, ELBO: nan
# EM Iteration 75/2000, ELBO: nan
# EM Iteration 76/2000, ELBO: nan
# EM Iteration 77/2000, ELBO: nan
# EM Iteration 78/2000, ELBO: nan
# EM Iteration 79/2000, ELBO: nan
# EM Iteration 80/2000, ELBO: nan
# EM Iteration 81/2000, ELBO: nan
# EM Iteration 82/2000, ELBO: nan
# EM Iteration 83/2000, ELBO: nan
# EM Iteration 84/2000, ELBO: nan
# EM Iteration 85/2000, ELBO: nan
# EM Iteration 86/2000, ELBO: nan
# EM Iteration 87/2000, ELBO: nan
# EM Iteration 88/2000, ELBO: nan
# EM Iteration 89/2000, ELBO: nan
# EM Iteration 90/2000, ELBO: nan
# EM Iteration 91/2000, ELBO: nan
# EM Iteration 92/2000, ELBO: nan
# EM Iteration 93/2000, ELBO: nan
# EM Iteration 94/2000, ELBO: nan
# EM Iteration 95/2000, ELBO: nan
# EM Iteration 96/2000, ELBO: nan
# EM Iteration 97/2000, ELBO: nan
# EM Iteration 98/2000, ELBO: nan
# EM Iteration 99/2000, ELBO: nan
# EM Iteration 100/2000, ELBO: nan
# EM Iteration 101/2000, ELBO: nan
# EM Iteration 102/2000, ELBO: nan
# EM Iteration 103/2000, ELBO: nan
# EM Iteration 104/2000, ELBO: nan
# EM Iteration 105/2000, ELBO: nan
# EM Iteration 106/2000, ELBO: nan
# EM Iteration 107/2000, ELBO: nan
# EM Iteration 108/2000, ELBO: nan
# EM Iteration 109/2000, ELBO: nan
# EM Iteration 110/2000, ELBO: nan
# EM Iteration 111/2000, ELBO: nan
# EM Iteration 112/2000, ELBO: nan
# EM Iteration 113/2000, ELBO: nan
# EM Iteration 114/2000, ELBO: nan
# EM Iteration 115/2000, ELBO: nan
# EM Iteration 116/2000, ELBO: nan
# EM Iteration 117/2000, ELBO: nan
# EM Iteration 118/2000, ELBO: nan
# EM Iteration 119/2000, ELBO: nan
# EM Iteration 120/2000, ELBO: nan
# EM Iteration 121/2000, ELBO: nan
# EM Iteration 122/2000, ELBO: nan
# EM Iteration 123/2000, ELBO: nan
# EM Iteration 124/2000, ELBO: nan
# EM Iteration 125/2000, ELBO: nan
# EM Iteration 126/2000, ELBO: nan
# EM Iteration 127/2000, ELBO: nan
# EM Iteration 128/2000, ELBO: nan
# EM Iteration 129/2000, ELBO: nan
# EM Iteration 130/2000, ELBO: nan
# EM Iteration 131/2000, ELBO: nan
# EM Iteration 132/2000, ELBO: nan
# EM Iteration 133/2000, ELBO: nan
# EM Iteration 134/2000, ELBO: nan
# EM Iteration 135/2000, ELBO: nan
# EM Iteration 136/2000, ELBO: nan
# EM Iteration 137/2000, ELBO: nan
# EM Iteration 138/2000, ELBO: nan
# EM Iteration 139/2000, ELBO: nan
# EM Iteration 140/2000, ELBO: nan
# EM Iteration 141/2000, ELBO: nan
# EM Iteration 142/2000, ELBO: nan
# EM Iteration 143/2000, ELBO: nan
# EM Iteration 144/2000, ELBO: nan
# EM Iteration 145/2000, ELBO: nan
# EM Iteration 146/2000, ELBO: nan
# EM Iteration 147/2000, ELBO: nan
# EM Iteration 148/2000, ELBO: nan
# EM Iteration 149/2000, ELBO: nan
# EM Iteration 150/2000, ELBO: nan
# EM Iteration 151/2000, ELBO: nan
# EM Iteration 152/2000, ELBO: nan
# EM Iteration 153/2000, ELBO: nan
# EM Iteration 154/2000, ELBO: nan
# EM Iteration 155/2000, ELBO: nan
# EM Iteration 156/2000, ELBO: nan
# EM Iteration 157/2000, ELBO: nan
# EM Iteration 158/2000, ELBO: nan
# EM Iteration 159/2000, ELBO: nan
# EM Iteration 160/2000, ELBO: nan
# EM Iteration 161/2000, ELBO: nan
# EM Iteration 162/2000, ELBO: nan
# EM Iteration 163/2000, ELBO: nan
# EM Iteration 164/2000, ELBO: nan
# EM Iteration 165/2000, ELBO: nan
# EM Iteration 166/2000, ELBO: nan
# EM Iteration 167/2000, ELBO: nan
# EM Iteration 168/2000, ELBO: nan
# EM Iteration 169/2000, ELBO: nan
# EM Iteration 170/2000, ELBO: nan
# EM Iteration 171/2000, ELBO: nan
# EM Iteration 172/2000, ELBO: nan
# EM Iteration 173/2000, ELBO: nan
# EM Iteration 174/2000, ELBO: nan
# EM Iteration 175/2000, ELBO: nan
# EM Iteration 176/2000, ELBO: nan
# EM Iteration 177/2000, ELBO: nan
# EM Iteration 178/2000, ELBO: nan
# EM Iteration 179/2000, ELBO: nan
# EM Iteration 180/2000, ELBO: nan
# EM Iteration 181/2000, ELBO: nan
# EM Iteration 182/2000, ELBO: nan
# EM Iteration 183/2000, ELBO: nan
# EM Iteration 184/2000, ELBO: nan
# EM Iteration 185/2000, ELBO: nan
# EM Iteration 186/2000, ELBO: nan
# EM Iteration 187/2000, ELBO: nan
# EM Iteration 188/2000, ELBO: nan
# EM Iteration 189/2000, ELBO: nan
# EM Iteration 190/2000, ELBO: nan
# EM Iteration 191/2000, ELBO: nan
# EM Iteration 192/2000, ELBO: nan
# EM Iteration 193/2000, ELBO: nan
# EM Iteration 194/2000, ELBO: nan
# EM Iteration 195/2000, ELBO: nan
# EM Iteration 196/2000, ELBO: nan
# EM Iteration 197/2000, ELBO: nan
# EM Iteration 198/2000, ELBO: nan
# EM Iteration 199/2000, ELBO: nan
# EM Iteration 200/2000, ELBO: nan
# EM Iteration 201/2000, ELBO: nan
# EM Iteration 202/2000, ELBO: nan
# EM Iteration 203/2000, ELBO: nan
# EM Iteration 204/2000, ELBO: nan
# EM Iteration 205/2000, ELBO: nan
# EM Iteration 206/2000, ELBO: nan
# EM Iteration 207/2000, ELBO: nan
# EM Iteration 208/2000, ELBO: nan
# EM Iteration 209/2000, ELBO: nan
# EM Iteration 210/2000, ELBO: nan
# EM Iteration 211/2000, ELBO: nan
# EM Iteration 212/2000, ELBO: nan
# EM Iteration 213/2000, ELBO: nan
# EM Iteration 214/2000, ELBO: nan
# EM Iteration 215/2000, ELBO: nan
# EM Iteration 216/2000, ELBO: nan
# EM Iteration 217/2000, ELBO: nan
# EM Iteration 218/2000, ELBO: nan
# EM Iteration 219/2000, ELBO: nan
# EM Iteration 220/2000, ELBO: nan
# EM Iteration 221/2000, ELBO: nan
# EM Iteration 222/2000, ELBO: nan
# EM Iteration 223/2000, ELBO: nan
# EM Iteration 224/2000, ELBO: nan
# EM Iteration 225/2000, ELBO: nan
# EM Iteration 226/2000, ELBO: nan
# EM Iteration 227/2000, ELBO: nan
# EM Iteration 228/2000, ELBO: nan
# EM Iteration 229/2000, ELBO: nan
# EM Iteration 230/2000, ELBO: nan
# EM Iteration 231/2000, ELBO: nan
# EM Iteration 232/2000, ELBO: nan
# EM Iteration 233/2000, ELBO: nan
# EM Iteration 234/2000, ELBO: nan
# EM Iteration 235/2000, ELBO: nan
# EM Iteration 236/2000, ELBO: nan
# EM Iteration 237/2000, ELBO: nan
# EM Iteration 238/2000, ELBO: nan
# EM Iteration 239/2000, ELBO: nan
# EM Iteration 240/2000, ELBO: nan
# EM Iteration 241/2000, ELBO: nan
# EM Iteration 242/2000, ELBO: nan
# EM Iteration 243/2000, ELBO: nan
# EM Iteration 244/2000, ELBO: nan
# EM Iteration 245/2000, ELBO: nan
# EM Iteration 246/2000, ELBO: nan
# EM Iteration 247/2000, ELBO: nan
# EM Iteration 248/2000, ELBO: nan
# EM Iteration 249/2000, ELBO: nan
# EM Iteration 250/2000, ELBO: nan
# EM Iteration 251/2000, ELBO: nan
# EM Iteration 252/2000, ELBO: nan
# EM Iteration 253/2000, ELBO: nan
# EM Iteration 254/2000, ELBO: nan
# EM Iteration 255/2000, ELBO: nan
# EM Iteration 256/2000, ELBO: nan
# EM Iteration 257/2000, ELBO: nan
# EM Iteration 258/2000, ELBO: nan
# EM Iteration 259/2000, ELBO: nan
# EM Iteration 260/2000, ELBO: nan
# EM Iteration 261/2000, ELBO: nan
# EM Iteration 262/2000, ELBO: nan
# EM Iteration 263/2000, ELBO: nan
# EM Iteration 264/2000, ELBO: nan
# EM Iteration 265/2000, ELBO: nan
# EM Iteration 266/2000, ELBO: nan
# EM Iteration 267/2000, ELBO: nan
# EM Iteration 268/2000, ELBO: nan
# EM Iteration 269/2000, ELBO: nan
# EM Iteration 270/2000, ELBO: nan
# EM Iteration 271/2000, ELBO: nan
# EM Iteration 272/2000, ELBO: nan
# EM Iteration 273/2000, ELBO: nan
# EM Iteration 274/2000, ELBO: nan
# EM Iteration 275/2000, ELBO: nan
# EM Iteration 276/2000, ELBO: nan
# EM Iteration 277/2000, ELBO: nan
# EM Iteration 278/2000, ELBO: nan
# EM Iteration 279/2000, ELBO: nan
# EM Iteration 280/2000, ELBO: nan
# EM Iteration 281/2000, ELBO: nan
# EM Iteration 282/2000, ELBO: nan
# EM Iteration 283/2000, ELBO: nan
# EM Iteration 284/2000, ELBO: nan
# EM Iteration 285/2000, ELBO: nan
# EM Iteration 286/2000, ELBO: nan
# EM Iteration 287/2000, ELBO: nan
# EM Iteration 288/2000, ELBO: nan
# EM Iteration 289/2000, ELBO: nan
# EM Iteration 290/2000, ELBO: nan
# EM Iteration 291/2000, ELBO: nan
# EM Iteration 292/2000, ELBO: nan
# EM Iteration 293/2000, ELBO: nan
# EM Iteration 294/2000, ELBO: nan
# EM Iteration 295/2000, ELBO: nan
# EM Iteration 296/2000, ELBO: nan
# EM Iteration 297/2000, ELBO: nan
# EM Iteration 298/2000, ELBO: nan
# EM Iteration 299/2000, ELBO: nan
# EM Iteration 300/2000, ELBO: nan
# EM Iteration 301/2000, ELBO: nan
# EM Iteration 302/2000, ELBO: nan
# EM Iteration 303/2000, ELBO: nan
# EM Iteration 304/2000, ELBO: nan
# EM Iteration 305/2000, ELBO: nan
# EM Iteration 306/2000, ELBO: nan
# EM Iteration 307/2000, ELBO: nan
# EM Iteration 308/2000, ELBO: nan
# EM Iteration 309/2000, ELBO: nan
# EM Iteration 310/2000, ELBO: nan
# EM Iteration 311/2000, ELBO: nan
# EM Iteration 312/2000, ELBO: nan
# EM Iteration 313/2000, ELBO: nan
# EM Iteration 314/2000, ELBO: nan
# EM Iteration 315/2000, ELBO: nan
# EM Iteration 316/2000, ELBO: nan
# EM Iteration 317/2000, ELBO: nan
# EM Iteration 318/2000, ELBO: nan
# EM Iteration 319/2000, ELBO: nan
# EM Iteration 320/2000, ELBO: nan
# EM Iteration 321/2000, ELBO: nan
# EM Iteration 322/2000, ELBO: nan
# EM Iteration 323/2000, ELBO: nan
# EM Iteration 324/2000, ELBO: nan
# EM Iteration 325/2000, ELBO: nan
# EM Iteration 326/2000, ELBO: nan
# EM Iteration 327/2000, ELBO: nan
# EM Iteration 328/2000, ELBO: nan
# EM Iteration 329/2000, ELBO: nan
# EM Iteration 330/2000, ELBO: nan
# EM Iteration 331/2000, ELBO: nan
# EM Iteration 332/2000, ELBO: nan
# EM Iteration 333/2000, ELBO: nan
# EM Iteration 334/2000, ELBO: nan
# EM Iteration 335/2000, ELBO: nan
# EM Iteration 336/2000, ELBO: nan
# EM Iteration 337/2000, ELBO: nan
# EM Iteration 338/2000, ELBO: nan
# EM Iteration 339/2000, ELBO: nan
# EM Iteration 340/2000, ELBO: nan
# EM Iteration 341/2000, ELBO: nan
# EM Iteration 342/2000, ELBO: nan
# EM Iteration 343/2000, ELBO: nan
# EM Iteration 344/2000, ELBO: nan
# EM Iteration 345/2000, ELBO: nan
# EM Iteration 346/2000, ELBO: nan
# EM Iteration 347/2000, ELBO: nan
# EM Iteration 348/2000, ELBO: nan
# EM Iteration 349/2000, ELBO: nan
# EM Iteration 350/2000, ELBO: nan
# EM Iteration 351/2000, ELBO: nan
# EM Iteration 352/2000, ELBO: nan
# EM Iteration 353/2000, ELBO: nan
# EM Iteration 354/2000, ELBO: nan
# EM Iteration 355/2000, ELBO: nan
# EM Iteration 356/2000, ELBO: nan
# EM Iteration 357/2000, ELBO: nan
# EM Iteration 358/2000, ELBO: nan
# EM Iteration 359/2000, ELBO: nan
# EM Iteration 360/2000, ELBO: nan
# EM Iteration 361/2000, ELBO: nan
# EM Iteration 362/2000, ELBO: nan
# EM Iteration 363/2000, ELBO: nan
# EM Iteration 364/2000, ELBO: nan
# EM Iteration 365/2000, ELBO: nan
# EM Iteration 366/2000, ELBO: nan
# EM Iteration 367/2000, ELBO: nan
# EM Iteration 368/2000, ELBO: nan
# EM Iteration 369/2000, ELBO: nan
# EM Iteration 370/2000, ELBO: nan
# EM Iteration 371/2000, ELBO: nan
# EM Iteration 372/2000, ELBO: nan
# EM Iteration 373/2000, ELBO: nan
# EM Iteration 374/2000, ELBO: nan
# EM Iteration 375/2000, ELBO: nan
# EM Iteration 376/2000, ELBO: nan
# EM Iteration 377/2000, ELBO: nan
# EM Iteration 378/2000, ELBO: nan
# EM Iteration 379/2000, ELBO: nan
# EM Iteration 380/2000, ELBO: nan
# EM Iteration 381/2000, ELBO: nan
# EM Iteration 382/2000, ELBO: nan
# EM Iteration 383/2000, ELBO: nan
# EM Iteration 384/2000, ELBO: nan
# EM Iteration 385/2000, ELBO: nan
# EM Iteration 386/2000, ELBO: nan
# EM Iteration 387/2000, ELBO: nan
# EM Iteration 388/2000, ELBO: nan
# EM Iteration 389/2000, ELBO: nan
# EM Iteration 390/2000, ELBO: nan
# EM Iteration 391/2000, ELBO: nan
# EM Iteration 392/2000, ELBO: nan
# EM Iteration 393/2000, ELBO: nan
# EM Iteration 394/2000, ELBO: nan
# EM Iteration 395/2000, ELBO: nan
# EM Iteration 396/2000, ELBO: nan
# EM Iteration 397/2000, ELBO: nan
# EM Iteration 398/2000, ELBO: nan
# EM Iteration 399/2000, ELBO: nan
# EM Iteration 400/2000, ELBO: nan
# EM Iteration 401/2000, ELBO: nan
# EM Iteration 402/2000, ELBO: nan
# EM Iteration 403/2000, ELBO: nan
# EM Iteration 404/2000, ELBO: nan
# EM Iteration 405/2000, ELBO: nan
# EM Iteration 406/2000, ELBO: nan
# EM Iteration 407/2000, ELBO: nan
# EM Iteration 408/2000, ELBO: nan
# EM Iteration 409/2000, ELBO: nan
# EM Iteration 410/2000, ELBO: nan
# EM Iteration 411/2000, ELBO: nan
# EM Iteration 412/2000, ELBO: nan
# EM Iteration 413/2000, ELBO: nan
# EM Iteration 414/2000, ELBO: nan
# EM Iteration 415/2000, ELBO: nan
# EM Iteration 416/2000, ELBO: nan
# EM Iteration 417/2000, ELBO: nan
# EM Iteration 418/2000, ELBO: nan
# EM Iteration 419/2000, ELBO: nan
# EM Iteration 420/2000, ELBO: nan
# EM Iteration 421/2000, ELBO: nan
# EM Iteration 422/2000, ELBO: nan
# EM Iteration 423/2000, ELBO: nan
# EM Iteration 424/2000, ELBO: nan
# EM Iteration 425/2000, ELBO: nan
# EM Iteration 426/2000, ELBO: nan
# EM Iteration 427/2000, ELBO: nan
# EM Iteration 428/2000, ELBO: nan
# EM Iteration 429/2000, ELBO: nan
# EM Iteration 430/2000, ELBO: nan
# EM Iteration 431/2000, ELBO: nan
# EM Iteration 432/2000, ELBO: nan
# EM Iteration 433/2000, ELBO: nan
# EM Iteration 434/2000, ELBO: nan
# EM Iteration 435/2000, ELBO: nan
# EM Iteration 436/2000, ELBO: nan
# EM Iteration 437/2000, ELBO: nan
# EM Iteration 438/2000, ELBO: nan
# EM Iteration 439/2000, ELBO: nan
# EM Iteration 440/2000, ELBO: nan
# EM Iteration 441/2000, ELBO: nan
# EM Iteration 442/2000, ELBO: nan
# EM Iteration 443/2000, ELBO: nan
# EM Iteration 444/2000, ELBO: nan
# EM Iteration 445/2000, ELBO: nan
# EM Iteration 446/2000, ELBO: nan
# EM Iteration 447/2000, ELBO: nan
# EM Iteration 448/2000, ELBO: nan
# EM Iteration 449/2000, ELBO: nan
# EM Iteration 450/2000, ELBO: nan
# EM Iteration 451/2000, ELBO: nan
# EM Iteration 452/2000, ELBO: nan
# EM Iteration 453/2000, ELBO: nan
# EM Iteration 454/2000, ELBO: nan
# EM Iteration 455/2000, ELBO: nan
# EM Iteration 456/2000, ELBO: nan
# EM Iteration 457/2000, ELBO: nan
# EM Iteration 458/2000, ELBO: nan
# EM Iteration 459/2000, ELBO: nan
# EM Iteration 460/2000, ELBO: nan
# EM Iteration 461/2000, ELBO: nan
# EM Iteration 462/2000, ELBO: nan
# EM Iteration 463/2000, ELBO: nan
# EM Iteration 464/2000, ELBO: nan
# EM Iteration 465/2000, ELBO: nan
# EM Iteration 466/2000, ELBO: nan
# EM Iteration 467/2000, ELBO: nan
# EM Iteration 468/2000, ELBO: nan
# EM Iteration 469/2000, ELBO: nan
# EM Iteration 470/2000, ELBO: nan
# EM Iteration 471/2000, ELBO: nan
# EM Iteration 472/2000, ELBO: nan
# EM Iteration 473/2000, ELBO: nan
# EM Iteration 474/2000, ELBO: nan
# EM Iteration 475/2000, ELBO: nan
# EM Iteration 476/2000, ELBO: nan
# EM Iteration 477/2000, ELBO: nan
# EM Iteration 478/2000, ELBO: nan
# EM Iteration 479/2000, ELBO: nan
# EM Iteration 480/2000, ELBO: nan
# EM Iteration 481/2000, ELBO: nan
# EM Iteration 482/2000, ELBO: nan
# EM Iteration 483/2000, ELBO: nan
# EM Iteration 484/2000, ELBO: nan
# EM Iteration 485/2000, ELBO: nan
# EM Iteration 486/2000, ELBO: nan
# EM Iteration 487/2000, ELBO: nan
# EM Iteration 488/2000, ELBO: nan
# EM Iteration 489/2000, ELBO: nan
# EM Iteration 490/2000, ELBO: nan
# EM Iteration 491/2000, ELBO: nan
# EM Iteration 492/2000, ELBO: nan
# EM Iteration 493/2000, ELBO: nan
# EM Iteration 494/2000, ELBO: nan
# EM Iteration 495/2000, ELBO: nan
# EM Iteration 496/2000, ELBO: nan
# EM Iteration 497/2000, ELBO: nan
# EM Iteration 498/2000, ELBO: nan
# EM Iteration 499/2000, ELBO: nan
# EM Iteration 500/2000, ELBO: nan
# EM Iteration 501/2000, ELBO: nan
# EM Iteration 502/2000, ELBO: nan
# EM Iteration 503/2000, ELBO: nan
# EM Iteration 504/2000, ELBO: nan
# EM Iteration 505/2000, ELBO: nan
# EM Iteration 506/2000, ELBO: nan
# EM Iteration 507/2000, ELBO: nan
# EM Iteration 508/2000, ELBO: nan
# EM Iteration 509/2000, ELBO: nan
# EM Iteration 510/2000, ELBO: nan
# EM Iteration 511/2000, ELBO: nan
# EM Iteration 512/2000, ELBO: nan
# EM Iteration 513/2000, ELBO: nan
# EM Iteration 514/2000, ELBO: nan
# EM Iteration 515/2000, ELBO: nan
# EM Iteration 516/2000, ELBO: nan
# EM Iteration 517/2000, ELBO: nan
# EM Iteration 518/2000, ELBO: nan
# EM Iteration 519/2000, ELBO: nan
# EM Iteration 520/2000, ELBO: nan
# EM Iteration 521/2000, ELBO: nan
# EM Iteration 522/2000, ELBO: nan
# EM Iteration 523/2000, ELBO: nan
# EM Iteration 524/2000, ELBO: nan
# EM Iteration 525/2000, ELBO: nan
# EM Iteration 526/2000, ELBO: nan
# EM Iteration 527/2000, ELBO: nan
# EM Iteration 528/2000, ELBO: nan
# EM Iteration 529/2000, ELBO: nan
# EM Iteration 530/2000, ELBO: nan
# EM Iteration 531/2000, ELBO: nan
# EM Iteration 532/2000, ELBO: nan
# EM Iteration 533/2000, ELBO: nan
# EM Iteration 534/2000, ELBO: nan
# EM Iteration 535/2000, ELBO: nan
# EM Iteration 536/2000, ELBO: nan
# EM Iteration 537/2000, ELBO: nan
# EM Iteration 538/2000, ELBO: nan
# EM Iteration 539/2000, ELBO: nan
# EM Iteration 540/2000, ELBO: nan
# EM Iteration 541/2000, ELBO: nan
# EM Iteration 542/2000, ELBO: nan
# EM Iteration 543/2000, ELBO: nan
# EM Iteration 544/2000, ELBO: nan
# EM Iteration 545/2000, ELBO: nan
# EM Iteration 546/2000, ELBO: nan
# EM Iteration 547/2000, ELBO: nan
# EM Iteration 548/2000, ELBO: nan
# EM Iteration 549/2000, ELBO: nan
# EM Iteration 550/2000, ELBO: nan
# EM Iteration 551/2000, ELBO: nan
# EM Iteration 552/2000, ELBO: nan
# EM Iteration 553/2000, ELBO: nan
# EM Iteration 554/2000, ELBO: nan
# EM Iteration 555/2000, ELBO: nan
# EM Iteration 556/2000, ELBO: nan
# EM Iteration 557/2000, ELBO: nan
# EM Iteration 558/2000, ELBO: nan
# EM Iteration 559/2000, ELBO: nan
# EM Iteration 560/2000, ELBO: nan
# EM Iteration 561/2000, ELBO: nan
# EM Iteration 562/2000, ELBO: nan
# EM Iteration 563/2000, ELBO: nan
# EM Iteration 564/2000, ELBO: nan
# EM Iteration 565/2000, ELBO: nan
# EM Iteration 566/2000, ELBO: nan
# EM Iteration 567/2000, ELBO: nan
# EM Iteration 568/2000, ELBO: nan
# EM Iteration 569/2000, ELBO: nan
# EM Iteration 570/2000, ELBO: nan
# EM Iteration 571/2000, ELBO: nan
# EM Iteration 572/2000, ELBO: nan
# EM Iteration 573/2000, ELBO: nan
# EM Iteration 574/2000, ELBO: nan
# EM Iteration 575/2000, ELBO: nan
# EM Iteration 576/2000, ELBO: nan
# EM Iteration 577/2000, ELBO: nan
# EM Iteration 578/2000, ELBO: nan
# EM Iteration 579/2000, ELBO: nan
# EM Iteration 580/2000, ELBO: nan
# EM Iteration 581/2000, ELBO: nan
# EM Iteration 582/2000, ELBO: nan
# EM Iteration 583/2000, ELBO: nan
# EM Iteration 584/2000, ELBO: nan
# EM Iteration 585/2000, ELBO: nan
# EM Iteration 586/2000, ELBO: nan
# EM Iteration 587/2000, ELBO: nan
# EM Iteration 588/2000, ELBO: nan
# EM Iteration 589/2000, ELBO: nan
# EM Iteration 590/2000, ELBO: nan
# EM Iteration 591/2000, ELBO: nan
# EM Iteration 592/2000, ELBO: nan
# EM Iteration 593/2000, ELBO: nan
# EM Iteration 594/2000, ELBO: nan
# EM Iteration 595/2000, ELBO: nan
# EM Iteration 596/2000, ELBO: nan
# EM Iteration 597/2000, ELBO: nan
# EM Iteration 598/2000, ELBO: nan
# EM Iteration 599/2000, ELBO: nan
# EM Iteration 600/2000, ELBO: nan
# EM Iteration 601/2000, ELBO: nan
# EM Iteration 602/2000, ELBO: nan
# EM Iteration 603/2000, ELBO: nan
# EM Iteration 604/2000, ELBO: nan
# EM Iteration 605/2000, ELBO: nan
# EM Iteration 606/2000, ELBO: nan
# EM Iteration 607/2000, ELBO: nan
# EM Iteration 608/2000, ELBO: nan
# EM Iteration 609/2000, ELBO: nan
# EM Iteration 610/2000, ELBO: nan
# EM Iteration 611/2000, ELBO: nan
# EM Iteration 612/2000, ELBO: nan
# EM Iteration 613/2000, ELBO: nan
# EM Iteration 614/2000, ELBO: nan
# EM Iteration 615/2000, ELBO: nan
# EM Iteration 616/2000, ELBO: nan
# EM Iteration 617/2000, ELBO: nan
# EM Iteration 618/2000, ELBO: nan
# EM Iteration 619/2000, ELBO: nan
# EM Iteration 620/2000, ELBO: nan
# EM Iteration 621/2000, ELBO: nan
# EM Iteration 622/2000, ELBO: nan
# EM Iteration 623/2000, ELBO: nan
# EM Iteration 624/2000, ELBO: nan
# EM Iteration 625/2000, ELBO: nan
# EM Iteration 626/2000, ELBO: nan
# EM Iteration 627/2000, ELBO: nan
# EM Iteration 628/2000, ELBO: nan
# EM Iteration 629/2000, ELBO: nan
# EM Iteration 630/2000, ELBO: nan
# EM Iteration 631/2000, ELBO: nan
# EM Iteration 632/2000, ELBO: nan
# EM Iteration 633/2000, ELBO: nan
# EM Iteration 634/2000, ELBO: nan
# EM Iteration 635/2000, ELBO: nan
# EM Iteration 636/2000, ELBO: nan
# EM Iteration 637/2000, ELBO: nan
# EM Iteration 638/2000, ELBO: nan
# EM Iteration 639/2000, ELBO: nan
# EM Iteration 640/2000, ELBO: nan
# EM Iteration 641/2000, ELBO: nan
# EM Iteration 642/2000, ELBO: nan
# EM Iteration 643/2000, ELBO: nan
# EM Iteration 644/2000, ELBO: nan
# EM Iteration 645/2000, ELBO: nan
# EM Iteration 646/2000, ELBO: nan
# EM Iteration 647/2000, ELBO: nan
# EM Iteration 648/2000, ELBO: nan
# EM Iteration 649/2000, ELBO: nan
# EM Iteration 650/2000, ELBO: nan
# EM Iteration 651/2000, ELBO: nan
# EM Iteration 652/2000, ELBO: nan
# EM Iteration 653/2000, ELBO: nan
# EM Iteration 654/2000, ELBO: nan
# EM Iteration 655/2000, ELBO: nan
# EM Iteration 656/2000, ELBO: nan
# EM Iteration 657/2000, ELBO: nan
# EM Iteration 658/2000, ELBO: nan
# EM Iteration 659/2000, ELBO: nan
# EM Iteration 660/2000, ELBO: nan
# EM Iteration 661/2000, ELBO: nan
# EM Iteration 662/2000, ELBO: nan
# EM Iteration 663/2000, ELBO: nan
# EM Iteration 664/2000, ELBO: nan
# EM Iteration 665/2000, ELBO: nan
# EM Iteration 666/2000, ELBO: nan
# EM Iteration 667/2000, ELBO: nan
# EM Iteration 668/2000, ELBO: nan
# EM Iteration 669/2000, ELBO: nan
# EM Iteration 670/2000, ELBO: nan
# EM Iteration 671/2000, ELBO: nan
# EM Iteration 672/2000, ELBO: nan
# EM Iteration 673/2000, ELBO: nan
# EM Iteration 674/2000, ELBO: nan
# EM Iteration 675/2000, ELBO: nan
# EM Iteration 676/2000, ELBO: nan
# EM Iteration 677/2000, ELBO: nan
# EM Iteration 678/2000, ELBO: nan
# EM Iteration 679/2000, ELBO: nan
# EM Iteration 680/2000, ELBO: nan
# EM Iteration 681/2000, ELBO: nan
# EM Iteration 682/2000, ELBO: nan
# EM Iteration 683/2000, ELBO: nan
# EM Iteration 684/2000, ELBO: nan
# EM Iteration 685/2000, ELBO: nan
# EM Iteration 686/2000, ELBO: nan
# EM Iteration 687/2000, ELBO: nan
# EM Iteration 688/2000, ELBO: nan
# EM Iteration 689/2000, ELBO: nan
# EM Iteration 690/2000, ELBO: nan
# EM Iteration 691/2000, ELBO: nan
# EM Iteration 692/2000, ELBO: nan
# EM Iteration 693/2000, ELBO: nan
# EM Iteration 694/2000, ELBO: nan
# EM Iteration 695/2000, ELBO: nan
# EM Iteration 696/2000, ELBO: nan
# EM Iteration 697/2000, ELBO: nan
# EM Iteration 698/2000, ELBO: nan
# EM Iteration 699/2000, ELBO: nan
# EM Iteration 700/2000, ELBO: nan
# EM Iteration 701/2000, ELBO: nan
# EM Iteration 702/2000, ELBO: nan
# EM Iteration 703/2000, ELBO: nan
# EM Iteration 704/2000, ELBO: nan
# EM Iteration 705/2000, ELBO: nan
# EM Iteration 706/2000, ELBO: nan
# EM Iteration 707/2000, ELBO: nan
# EM Iteration 708/2000, ELBO: nan
# EM Iteration 709/2000, ELBO: nan
# EM Iteration 710/2000, ELBO: nan
# EM Iteration 711/2000, ELBO: nan
# EM Iteration 712/2000, ELBO: nan
# EM Iteration 713/2000, ELBO: nan
# EM Iteration 714/2000, ELBO: nan
# EM Iteration 715/2000, ELBO: nan
# EM Iteration 716/2000, ELBO: nan
# EM Iteration 717/2000, ELBO: nan
# EM Iteration 718/2000, ELBO: nan
# EM Iteration 719/2000, ELBO: nan
# EM Iteration 720/2000, ELBO: nan
# EM Iteration 721/2000, ELBO: nan
# EM Iteration 722/2000, ELBO: nan
# EM Iteration 723/2000, ELBO: nan
# EM Iteration 724/2000, ELBO: nan
# EM Iteration 725/2000, ELBO: nan
# EM Iteration 726/2000, ELBO: nan
# EM Iteration 727/2000, ELBO: nan
# EM Iteration 728/2000, ELBO: nan
# EM Iteration 729/2000, ELBO: nan
# EM Iteration 730/2000, ELBO: nan
# EM Iteration 731/2000, ELBO: nan
# EM Iteration 732/2000, ELBO: nan
# EM Iteration 733/2000, ELBO: nan
# EM Iteration 734/2000, ELBO: nan
# EM Iteration 735/2000, ELBO: nan
# EM Iteration 736/2000, ELBO: nan
# EM Iteration 737/2000, ELBO: nan
# EM Iteration 738/2000, ELBO: nan
# EM Iteration 739/2000, ELBO: nan
# EM Iteration 740/2000, ELBO: nan
# EM Iteration 741/2000, ELBO: nan
# EM Iteration 742/2000, ELBO: nan
# EM Iteration 743/2000, ELBO: nan
# EM Iteration 744/2000, ELBO: nan
# EM Iteration 745/2000, ELBO: nan
# EM Iteration 746/2000, ELBO: nan
# EM Iteration 747/2000, ELBO: nan
# EM Iteration 748/2000, ELBO: nan
# EM Iteration 749/2000, ELBO: nan
# EM Iteration 750/2000, ELBO: nan
# EM Iteration 751/2000, ELBO: nan
# EM Iteration 752/2000, ELBO: nan
# EM Iteration 753/2000, ELBO: nan
# EM Iteration 754/2000, ELBO: nan
# EM Iteration 755/2000, ELBO: nan
# EM Iteration 756/2000, ELBO: nan
# EM Iteration 757/2000, ELBO: nan
# EM Iteration 758/2000, ELBO: nan
# EM Iteration 759/2000, ELBO: nan
# EM Iteration 760/2000, ELBO: nan
# EM Iteration 761/2000, ELBO: nan
# EM Iteration 762/2000, ELBO: nan
# EM Iteration 763/2000, ELBO: nan
# EM Iteration 764/2000, ELBO: nan
# EM Iteration 765/2000, ELBO: nan
# EM Iteration 766/2000, ELBO: nan
# EM Iteration 767/2000, ELBO: nan
# EM Iteration 768/2000, ELBO: nan
# EM Iteration 769/2000, ELBO: nan
# EM Iteration 770/2000, ELBO: nan
# EM Iteration 771/2000, ELBO: nan
# EM Iteration 772/2000, ELBO: nan
# EM Iteration 773/2000, ELBO: nan
# EM Iteration 774/2000, ELBO: nan
# EM Iteration 775/2000, ELBO: nan
# EM Iteration 776/2000, ELBO: nan
# EM Iteration 777/2000, ELBO: nan
# EM Iteration 778/2000, ELBO: nan
# EM Iteration 779/2000, ELBO: nan
# EM Iteration 780/2000, ELBO: nan
# EM Iteration 781/2000, ELBO: nan
# EM Iteration 782/2000, ELBO: nan
# EM Iteration 783/2000, ELBO: nan
# EM Iteration 784/2000, ELBO: nan
# EM Iteration 785/2000, ELBO: nan
# EM Iteration 786/2000, ELBO: nan
# EM Iteration 787/2000, ELBO: nan
# EM Iteration 788/2000, ELBO: nan
# EM Iteration 789/2000, ELBO: nan
# EM Iteration 790/2000, ELBO: nan
# EM Iteration 791/2000, ELBO: nan
# EM Iteration 792/2000, ELBO: nan
# EM Iteration 793/2000, ELBO: nan
# EM Iteration 794/2000, ELBO: nan
# EM Iteration 795/2000, ELBO: nan
# EM Iteration 796/2000, ELBO: nan
# EM Iteration 797/2000, ELBO: nan
# EM Iteration 798/2000, ELBO: nan
# EM Iteration 799/2000, ELBO: nan
# EM Iteration 800/2000, ELBO: nan
# EM Iteration 801/2000, ELBO: nan
# EM Iteration 802/2000, ELBO: nan
# EM Iteration 803/2000, ELBO: nan
# EM Iteration 804/2000, ELBO: nan
# EM Iteration 805/2000, ELBO: nan
# EM Iteration 806/2000, ELBO: nan
# EM Iteration 807/2000, ELBO: nan
# EM Iteration 808/2000, ELBO: nan
# EM Iteration 809/2000, ELBO: nan
# EM Iteration 810/2000, ELBO: nan
# EM Iteration 811/2000, ELBO: nan
# EM Iteration 812/2000, ELBO: nan
# EM Iteration 813/2000, ELBO: nan
# EM Iteration 814/2000, ELBO: nan
# EM Iteration 815/2000, ELBO: nan
# EM Iteration 816/2000, ELBO: nan
# EM Iteration 817/2000, ELBO: nan
# EM Iteration 818/2000, ELBO: nan
# EM Iteration 819/2000, ELBO: nan
# EM Iteration 820/2000, ELBO: nan
# EM Iteration 821/2000, ELBO: nan
# EM Iteration 822/2000, ELBO: nan
# EM Iteration 823/2000, ELBO: nan
# EM Iteration 824/2000, ELBO: nan
# EM Iteration 825/2000, ELBO: nan
# EM Iteration 826/2000, ELBO: nan
# EM Iteration 827/2000, ELBO: nan
# EM Iteration 828/2000, ELBO: nan
# EM Iteration 829/2000, ELBO: nan
# EM Iteration 830/2000, ELBO: nan
# EM Iteration 831/2000, ELBO: nan
# EM Iteration 832/2000, ELBO: nan
# EM Iteration 833/2000, ELBO: nan
# EM Iteration 834/2000, ELBO: nan
# EM Iteration 835/2000, ELBO: nan
# EM Iteration 836/2000, ELBO: nan
# EM Iteration 837/2000, ELBO: nan
# EM Iteration 838/2000, ELBO: nan
# EM Iteration 839/2000, ELBO: nan
# EM Iteration 840/2000, ELBO: nan
# EM Iteration 841/2000, ELBO: nan
# EM Iteration 842/2000, ELBO: nan
# EM Iteration 843/2000, ELBO: nan
# EM Iteration 844/2000, ELBO: nan
# EM Iteration 845/2000, ELBO: nan
# EM Iteration 846/2000, ELBO: nan
# EM Iteration 847/2000, ELBO: nan
# EM Iteration 848/2000, ELBO: nan
# EM Iteration 849/2000, ELBO: nan
# EM Iteration 850/2000, ELBO: nan
# EM Iteration 851/2000, ELBO: nan
# EM Iteration 852/2000, ELBO: nan
# EM Iteration 853/2000, ELBO: nan
# EM Iteration 854/2000, ELBO: nan
# EM Iteration 855/2000, ELBO: nan
# EM Iteration 856/2000, ELBO: nan
# EM Iteration 857/2000, ELBO: nan
# EM Iteration 858/2000, ELBO: nan
# EM Iteration 859/2000, ELBO: nan
# EM Iteration 860/2000, ELBO: nan
# EM Iteration 861/2000, ELBO: nan
# EM Iteration 862/2000, ELBO: nan
# EM Iteration 863/2000, ELBO: nan
# EM Iteration 864/2000, ELBO: nan
# EM Iteration 865/2000, ELBO: nan
# EM Iteration 866/2000, ELBO: nan
# EM Iteration 867/2000, ELBO: nan
# EM Iteration 868/2000, ELBO: nan
# EM Iteration 869/2000, ELBO: nan
# EM Iteration 870/2000, ELBO: nan
# EM Iteration 871/2000, ELBO: nan
# EM Iteration 872/2000, ELBO: nan
# EM Iteration 873/2000, ELBO: nan
# EM Iteration 874/2000, ELBO: nan
# EM Iteration 875/2000, ELBO: nan
# EM Iteration 876/2000, ELBO: nan
# EM Iteration 877/2000, ELBO: nan
# EM Iteration 878/2000, ELBO: nan
# EM Iteration 879/2000, ELBO: nan
# EM Iteration 880/2000, ELBO: nan
# EM Iteration 881/2000, ELBO: nan
# EM Iteration 882/2000, ELBO: nan
# EM Iteration 883/2000, ELBO: nan
# EM Iteration 884/2000, ELBO: nan
# EM Iteration 885/2000, ELBO: nan
# EM Iteration 886/2000, ELBO: nan
# EM Iteration 887/2000, ELBO: nan
# EM Iteration 888/2000, ELBO: nan
# EM Iteration 889/2000, ELBO: nan
# EM Iteration 890/2000, ELBO: nan
# EM Iteration 891/2000, ELBO: nan
# EM Iteration 892/2000, ELBO: nan
# EM Iteration 893/2000, ELBO: nan
# EM Iteration 894/2000, ELBO: nan
# EM Iteration 895/2000, ELBO: nan
# EM Iteration 896/2000, ELBO: nan
# EM Iteration 897/2000, ELBO: nan
# EM Iteration 898/2000, ELBO: nan
# EM Iteration 899/2000, ELBO: nan
# EM Iteration 900/2000, ELBO: nan
# EM Iteration 901/2000, ELBO: nan
# EM Iteration 902/2000, ELBO: nan
# EM Iteration 903/2000, ELBO: nan
# EM Iteration 904/2000, ELBO: nan
# EM Iteration 905/2000, ELBO: nan
# EM Iteration 906/2000, ELBO: nan
# EM Iteration 907/2000, ELBO: nan
# EM Iteration 908/2000, ELBO: nan
# EM Iteration 909/2000, ELBO: nan
# EM Iteration 910/2000, ELBO: nan
# EM Iteration 911/2000, ELBO: nan
# EM Iteration 912/2000, ELBO: nan
# EM Iteration 913/2000, ELBO: nan
# EM Iteration 914/2000, ELBO: nan
# EM Iteration 915/2000, ELBO: nan
# EM Iteration 916/2000, ELBO: nan
# EM Iteration 917/2000, ELBO: nan
# EM Iteration 918/2000, ELBO: nan
# EM Iteration 919/2000, ELBO: nan
# EM Iteration 920/2000, ELBO: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 211
#     207 y_train[70] = 5.0
#     210 model = TPRegressionVariationalEM(X_train, y_train, M=20)
# --> 211 model.fit(em_iterations=2000, cavi_per_step=5)
#
# Cell In[3], line 182, in TPRegressionVariationalEM.fit(self, em_iterations, cavi_per_step)
#     179     self._e_step(cavi_iterations=cavi_per_step)
#     181     # M-Step: Update hyperparameters
# --> 182     elbo = self._m_step()
#     184     print(f"EM Iteration {i+1}/{em_iterations}, ELBO: {elbo:.4f}")
#     186 print("\nOptimization finished.")
#
# Cell In[3], line 168, in TPRegressionVariationalEM._m_step(self, iterations)
#     166     elbo = self._calculate_elbo()
#     167     loss = -elbo # We maximize ELBO, so we minimize -ELBO
# --> 168     loss.backward()
#     169     self.optimizer.step()
#     170 return elbo.item()
#
# File ~/ws/tprt/.venv-tprt/lib/python3.11/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)    646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/ws/tprt/.venv-tprt/lib/python3.11/site-packages/torch/autograd/__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File ~/ws/tprt/.venv-tprt/lib/python3.11/site-packages/torch/autograd/graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from scipy.stats import t
import math

def rbf_kernel(X1, X2, lengthscale=1.0, variance=1.0):
    """
    Computes the RBF kernel matrix between two sets of points.
    """
    # Ensure lengthscale and variance are tensors for autograd
    lengthscale = torch.as_tensor(lengthscale, dtype=X1.dtype, device=X1.device)
    variance = torch.as_tensor(variance, dtype=X1.dtype, device=X1.device)
    
    sqdist = torch.cdist(X1, X2, p=2).pow(2)
    return variance * torch.exp(-0.5 * sqdist / lengthscale**2)

class TPRegression:
    """
    Implementation of Variational EM for Student-t Process Regression.
    - E-Step: CAVI updates for variational parameters.
    - M-Step: Gradient-based optimization of model hyperparameters and inducing points.
    """
    def __init__(self, X, y, Z_initial, nu_f=5.0, nu_e=5.0, kernel_lengthscale=1.0, kernel_variance=1.0, likelihood_sigma=1.0):
        self.X = X
        self.y = y.squeeze()
        self.N, self.D = X.shape
        self.M = Z_initial.shape[0]

        # --- Initialize Hyperparameters and Inducing Points (M-step) ---
        # These are now learnable parameters. We optimize their log for stability.
        self.log_nu_f = torch.nn.Parameter(torch.log(torch.tensor(nu_f)))
        self.log_nu_epsilon = torch.nn.Parameter(torch.log(torch.tensor(nu_e)))
        self.log_sigma_sq = torch.nn.Parameter(torch.log(torch.tensor(likelihood_sigma**2)))
        self.log_kernel_lengthscale = torch.nn.Parameter(torch.log(torch.tensor(kernel_lengthscale)))
        self.log_kernel_variance = torch.nn.Parameter(torch.log(torch.tensor(kernel_variance)))
        self.Z = torch.nn.Parameter(Z_initial.clone())

        # --- Initialize Variational Parameters (E-step) ---
        self.m_u = torch.zeros(self.M, 1)
        self.S_u = torch.eye(self.M)
        self.alpha_r = torch.tensor(1.0)
        self.beta_r = torch.tensor(1.0)
        self.alpha_lambda = torch.ones(self.N)
        self.beta_lambda = torch.ones(self.N)
        
    def _get_hyperparams(self):
        """Returns the exponentiated (positive) hyperparameters."""
        return {
            "nu_f": torch.exp(self.log_nu_f),
            "nu_epsilon": torch.exp(self.log_nu_epsilon),
            "sigma_sq": torch.exp(self.log_sigma_sq),
            "lengthscale": torch.exp(self.log_kernel_lengthscale),
            "variance": torch.exp(self.log_kernel_variance)
        }
        
    def _e_step(self, cavi_max_iter=1):
        """Performs the CAVI updates for the variational parameters (E-Step)."""
        with torch.no_grad(): # No gradients needed for the E-step updates
            params = self._get_hyperparams()
            K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
            K_ZZ_inv = torch.inverse(K_ZZ)
            K_XZ = rbf_kernel(self.X, self.Z, params['lengthscale'], params['variance'])
            
            for _ in range(cavi_max_iter):
                # Update q(lambda)
                K_ZZ_inv_m_u = torch.linalg.solve(K_ZZ, self.m_u)
                expected_f_mean = K_XZ @ K_ZZ_inv_m_u
                if self.alpha_r > 1: expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
                else: expected_r_inv = self.beta_r
                k_ii = torch.diag(rbf_kernel(self.X, self.X, params['lengthscale'], params['variance']))
                K_XZ_K_ZZ_inv = K_XZ @ K_ZZ_inv
                var_f_term1 = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * K_XZ).sum(dim=1))
                var_f_term2 = (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
                var_f = var_f_term1 + var_f_term2
                expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f
                self.alpha_lambda = params['nu_epsilon'] / 2.0 + 0.5
                self.beta_lambda = params['nu_epsilon'] / 2.0 + (0.5 / params['sigma_sq']) * expected_sq_error

                # Update q(r)
                trace_term = torch.trace(K_ZZ_inv @ self.S_u)
                mean_term = self.m_u.T @ K_ZZ_inv @ self.m_u
                expected_u_quadratic_form = trace_term + mean_term
                self.alpha_r = params['nu_f'] / 2.0 + self.M / 2.0
                self.beta_r = params['nu_f'] / 2.0 + 0.5 * expected_u_quadratic_form.squeeze()

                # Update q(u)
                expected_r = self.alpha_r / self.beta_r
                expected_lambda = self.alpha_lambda / self.beta_lambda
                precision_u_prior = expected_r * K_ZZ_inv
                K_ZX = K_XZ.T
                A = K_ZX * (expected_lambda / params['sigma_sq'])
                B = A @ K_XZ
                precision_u_lik = K_ZZ_inv.T @ B @ K_ZZ_inv
                precision_u = precision_u_prior + precision_u_lik
                self.S_u = torch.inverse(precision_u + torch.eye(self.M) * 1e-6)
                b = K_ZZ_inv.T @ (K_ZX @ (expected_lambda * self.y / params['sigma_sq']))
                self.m_u = (self.S_u @ b).unsqueeze(1)

    def _calculate_elbo(self):
        """Calculates the Evidence Lower Bound (ELBO) for the M-step."""
        params = self._get_hyperparams()
        
        K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
        K_ZZ_inv = torch.inverse(K_ZZ)
        K_XZ = rbf_kernel(self.X, self.Z, params['lengthscale'], params['variance'])
        k_ii = torch.diag(rbf_kernel(self.X, self.X, params['lengthscale'], params['variance']))

        # 1. Expected Log-Likelihood
        expected_log_lambda = torch.digamma(self.alpha_lambda) - torch.log(self.beta_lambda)
        expected_lambda = self.alpha_lambda / self.beta_lambda
        K_ZZ_inv_m_u = torch.linalg.solve(K_ZZ, self.m_u)
        expected_f_mean = K_XZ @ K_ZZ_inv_m_u
        if self.alpha_r > 1: expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
        else: expected_r_inv = self.beta_r
        K_XZ_K_ZZ_inv = K_XZ @ K_ZZ_inv
        var_f = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * K_XZ).sum(dim=1)) + \
                (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
        expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f
        
        log_lik = 0.5 * torch.sum(expected_log_lambda - math.log(2 * math.pi) - torch.log(params['sigma_sq']) - \
                                  expected_lambda / params['sigma_sq'] * expected_sq_error)

        # 2. KL Divergences
        p_alpha_r, p_beta_r = params['nu_f'] / 2.0, params['nu_f'] / 2.0
        kl_r = (self.alpha_r - p_alpha_r) * torch.digamma(self.alpha_r) - torch.lgamma(self.alpha_r) + torch.lgamma(p_alpha_r) + \
               p_alpha_r * (torch.log(self.beta_r) - torch.log(p_beta_r)) + self.alpha_r * (p_beta_r - self.beta_r) / self.beta_r
        
        expected_log_r = torch.digamma(self.alpha_r) - torch.log(self.beta_r)
        kl_u = 0.5 * (
            -torch.logdet(self.S_u) - self.M * expected_log_r + torch.logdet(K_ZZ) + \
            (self.alpha_r / self.beta_r) * (torch.trace(K_ZZ_inv @ self.S_u) + self.m_u.T @ K_ZZ_inv @ self.m_u) - self.M
        ).squeeze()
        
        # CORRECTED a typo here: params['nu_e'] -> params['nu_epsilon']
        p_alpha_lambda, p_beta_lambda = params['nu_epsilon'] / 2.0, params['nu_epsilon'] / 2.0
        kl_lambda = torch.sum((self.alpha_lambda - p_alpha_lambda) * torch.digamma(self.alpha_lambda) - \
                    torch.lgamma(self.alpha_lambda) + torch.lgamma(p_alpha_lambda) + \
                    p_alpha_lambda * (torch.log(self.beta_lambda) - torch.log(p_beta_lambda)) + \
                    self.alpha_lambda * (p_beta_lambda - self.beta_lambda) / self.beta_lambda)

        return log_lik - kl_u - kl_r - kl_lambda

    def _m_step(self, optimizer):
        """Performs the gradient update for the hyperparameters (M-Step)."""
        optimizer.zero_grad()
        elbo = self._calculate_elbo()
        loss = -elbo # Maximize ELBO by minimizing -ELBO
        loss.backward()
        optimizer.step()
        return elbo.item()

    def fit(self, max_iter_global=100, cavi_max_iter=10, lr=0.01):
        """Runs the full Variational EM algorithm."""
        optimizer = optim.Adam(
            [self.log_nu_f, self.log_nu_epsilon, self.log_sigma_sq,
             self.log_kernel_lengthscale, self.log_kernel_variance, self.Z],
            lr=lr
        )
        
        elbo_history = []
        print("Starting Variational EM optimization...")
        for i in range(max_iter_global):
            self._e_step(cavi_max_iter=cavi_max_iter)
            elbo = self._m_step(optimizer)
            elbo_history.append(elbo)
            
            if (i + 1) % 50 == 0:
                print(f"EM Iteration {i+1}/{max_iter_global}, ELBO: {elbo:.4f}")
        
        print("\nOptimization finished.")
        return elbo_history

    def predict(self, X_test):
        """
        Makes predictions for new data X_test.
        Returns the parameters of the predictive Student-t distribution.
        """
        with torch.no_grad():
            params = self._get_hyperparams()
            
            K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
            K_ZZ_inv = torch.inverse(K_ZZ)
            K_star_Z = rbf_kernel(X_test, self.Z, params['lengthscale'], params['variance'])
            k_star_star = torch.diag(rbf_kernel(X_test, X_test, params['lengthscale'], params['variance']))

            K_ZZ_inv_m_u = torch.linalg.solve(K_ZZ, self.m_u)
            pred_mean = (K_star_Z @ K_ZZ_inv_m_u).squeeze()

            K_star_Z_K_ZZ_inv = K_star_Z @ K_ZZ_inv
            gp_var = k_star_star - (K_star_Z_K_ZZ_inv * K_star_Z).sum(dim=1) + \
                     (K_star_Z_K_ZZ_inv @ self.S_u * K_star_Z_K_ZZ_inv).sum(dim=1)
            
            pred_nu = 2 * self.alpha_r
            pred_scale_sq = gp_var * (self.beta_r / self.alpha_r)
            
            return pred_mean, pred_scale_sq, pred_nu

if __name__ == '__main__':
    # 1. Generate data
    N = 100
    X_train = torch.linspace(-5, 5, N).unsqueeze(1)
    y_true = torch.sin(X_train) * 2
    noise = torch.randn(N, 1) * 0.1
    t_dist_sample = torch.distributions.StudentT(df=2)
    outlier_noise = t_dist_sample.sample((N, 1)) * 0.5
    y_train = y_true + noise
    outlier_indices = torch.randperm(N)[:10]
    y_train[outlier_indices] += outlier_noise[outlier_indices] * 3
    y_train[30] = -4.0
    y_train[70] = 5.0

    # 2. Setup the model with INITIAL inducing points
    M = 20
    Z_initial = torch.linspace(-5, 5, M).unsqueeze(1)

    model = TPRegression(
        X=X_train,
        y=y_train,
        Z_initial=Z_initial,
        nu_f=5.0,
        nu_e=5.0,
        kernel_lengthscale=0.5,
        kernel_variance=2.0,
        likelihood_sigma=0.5
    )

    # 3. Fit the model and get ELBO history
    elbo_history = model.fit(max_iter_global=2000, cavi_max_iter=5, lr=0.01)

    # Print final Z locations
    print("\n--- Initial Z ---")
    print(Z_initial.squeeze().numpy())
    print("\n--- Optimized Z ---")
    print(model.Z.detach().squeeze().numpy())
    print("-------------------")

    # 4. Make predictions
    X_test = torch.linspace(-6, 6, 200).unsqueeze(1)
    pred_mean, pred_var, pred_nu = model.predict(X_test)

    # 5. Visualize the regression results
    plt.figure(figsize=(12, 8))

    pred_scale = torch.sqrt(pred_var.clamp(min=1e-9))
    df = pred_nu.item()
    lower_quantile = t.ppf(0.025, df=df)
    upper_quantile = t.ppf(0.975, df=df)
    lower = pred_mean + lower_quantile * pred_scale
    upper = pred_mean + upper_quantile * pred_scale

    plt.fill_between(X_test.squeeze(), lower.squeeze(), upper.squeeze(), color='orange', alpha=0.3, label='95% Predictive Interval (Student-t)')
    plt.plot(X_test, pred_mean, 'r-', lw=2, label='Predictive Mean')
    plt.plot(X_train, y_train, 'kx', mew=2, label='Training Data (with outliers)')
    plt.plot(model.Z.detach(), torch.full_like(model.Z.detach(), -5.5), 'r|', ms=20, mew=2, label='Optimized Inducing Points')

    plt.title('Sparse TP Regression (with Z and Hyperparameter Optimization)', fontsize=16)
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.xlim(-6, 6)
    plt.ylim(-6, 6)
    
    # 6. Visualize ELBO history
    plt.figure(figsize=(12, 6))
    plt.plot(range(1, len(elbo_history) + 1), elbo_history, marker='.', linestyle='-')
    plt.title('Sparse TP ELBO Convergence', fontsize=16)
    plt.xlabel('Iteration', fontsize=12)
    plt.ylabel('ELBO', fontsize=12)
    plt.grid(True)
    plt.tight_layout()

    plt.show()
# Out:
# Starting Variational EM optimization...
# EM Iteration 50/2000, ELBO: -99.6548
# EM Iteration 100/2000, ELBO: -90.2910
# EM Iteration 150/2000, ELBO: nan
# EM Iteration 200/2000, ELBO: nan
# EM Iteration 250/2000, ELBO: nan
# EM Iteration 300/2000, ELBO: nan
# EM Iteration 350/2000, ELBO: nan
# EM Iteration 400/2000, ELBO: nan
# EM Iteration 450/2000, ELBO: nan
# EM Iteration 500/2000, ELBO: nan
# EM Iteration 550/2000, ELBO: nan
# EM Iteration 600/2000, ELBO: nan
# EM Iteration 650/2000, ELBO: nan
# EM Iteration 700/2000, ELBO: nan
# EM Iteration 750/2000, ELBO: nan
# EM Iteration 800/2000, ELBO: nan
# EM Iteration 850/2000, ELBO: nan
# EM Iteration 900/2000, ELBO: nan
# EM Iteration 950/2000, ELBO: nan
# EM Iteration 1000/2000, ELBO: nan
# EM Iteration 1050/2000, ELBO: nan
# EM Iteration 1100/2000, ELBO: nan
# EM Iteration 1150/2000, ELBO: nan
# EM Iteration 1200/2000, ELBO: nan
# EM Iteration 1250/2000, ELBO: nan
# EM Iteration 1300/2000, ELBO: nan
# EM Iteration 1350/2000, ELBO: nan
# EM Iteration 1400/2000, ELBO: nan
# EM Iteration 1450/2000, ELBO: nan
# EM Iteration 1500/2000, ELBO: nan
# EM Iteration 1550/2000, ELBO: nan
# EM Iteration 1600/2000, ELBO: nan
# EM Iteration 1650/2000, ELBO: nan
# EM Iteration 1700/2000, ELBO: nan
# EM Iteration 1750/2000, ELBO: nan
# EM Iteration 1800/2000, ELBO: nan
# EM Iteration 1850/2000, ELBO: nan
# EM Iteration 1900/2000, ELBO: nan
# EM Iteration 1950/2000, ELBO: nan
# EM Iteration 2000/2000, ELBO: nan
#
# Optimization finished.
#
# --- Initial Z ---
# [-5.         -4.4736843  -3.9473684  -3.4210525  -2.8947368  -2.368421
#  -1.8421052  -1.3157893  -0.78947353 -0.26315773  0.26315773  0.78947353
#   1.3157893   1.8421052   2.368421    2.8947368   3.4210525   3.9473684
#   4.4736843   5.        ]
#
# --- Optimized Z ---
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
# -------------------

# %%
import torch

# A placeholder for a kernel function (e.g., RBF)
def rbf_kernel(X1, X2, lengthscale=1.0, variance=1.0):
    """
    Computes the RBF kernel matrix between two sets of points.
    """
    sqdist = torch.cdist(X1, X2, p=2).pow(2)
    return variance * torch.exp(-0.5 * sqdist / lengthscale**2)

class TPRegressionCAVI:
    """
    PyTorch implementation of CAVI for Student-t Process Regression
    with a Student-t Likelihood, based on the provided document.
    """
    def __init__(self, X, y, M=20, nu_f=5.0, nu_epsilon=5.0, sigma_sq=1.0):
        """
        Initializes the model and variational parameters. [cite: 133]

        Args:
            X (torch.Tensor): Training inputs (N x D).
            y (torch.Tensor): Training outputs (N x 1).
            M (int): Number of inducing points.
            nu_f (float): Degrees of freedom for the TP prior. [cite: 13]
            nu_epsilon (float): Degrees of freedom for the likelihood. [cite: 19]
            sigma_sq (float): Scale parameter for the likelihood noise. [cite: 19]
        """
        self.X = X
        self.y = y.squeeze()
        self.N, self.D = X.shape
        self.M = M

        # Initialize hyperparameters [cite: 133]
        self.nu_f = torch.tensor(nu_f)
        self.nu_epsilon = torch.tensor(nu_epsilon)
        self.sigma_sq = torch.tensor(sigma_sq)
        self.kernel = rbf_kernel

        # Initialize inducing points Z by selecting M random points from X
        indices = torch.randperm(self.N)[:self.M]
        self.Z = self.X[indices].clone()

        # Pre-compute kernel matrices
        self.K_ZZ = self.kernel(self.Z, self.Z) + torch.eye(self.M) * 1e-6
        self.K_ZZ_inv = torch.inverse(self.K_ZZ)
        self.K_XZ = self.kernel(self.X, self.Z)
        
        # --- Initialize Variational Parameters --- [cite: 133]
        # q(u) = N(m_u, S_u)
        self.m_u = torch.zeros(self.M, 1) # [cite: 47]
        self.S_u = torch.eye(self.M)       # [cite: 47]

        # q(r) = Gamma(alpha_r, beta_r)
        self.alpha_r = torch.tensor(1.0) # [cite: 49]
        self.beta_r = torch.tensor(1.0)  # [cite: 49]

        # q(lambda_i) = Gamma(alpha_lambda_i, beta_lambda_i)
        self.alpha_lambda = torch.ones(self.N) # [cite: 51]
        self.beta_lambda = torch.ones(self.N)  # [cite: 51]

    def _update_q_lambda(self):
        """
        Updates the variational parameters for q(lambda_i) for all i=1..N.
        This corresponds to lines 5-8 in Algorithm 1. [cite: 137, 143]
        """
        # 1. Compute expected squared error E_q[(y_i - f_i)^2] [cite: 141]
        # E_q[(y_i - f_i)^2] = (y_i - E[f_i])^2 + Var(f_i) [cite: 112]
        
        # Calculate E[f_i] = k_i,Z * K_ZZ^-1 * m_u [cite: 114]
        K_ZZ_inv_m_u = torch.linalg.solve(self.K_ZZ, self.m_u)
        expected_f_mean = self.K_XZ @ K_ZZ_inv_m_u

        # Calculate Var(f_i) [cite: 116, 118]
        # We need E[r^-1] = beta_r / (alpha_r - 1) for alpha_r > 1 [cite: 119]
        if self.alpha_r > 1:
            expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
        else:
            expected_r_inv = self.beta_r # Fallback for stability at initialization
        
        k_ii = torch.diag(self.kernel(self.X, self.X))
        K_XZ_K_ZZ_inv = self.K_XZ @ self.K_ZZ_inv
        
        var_f_term1 = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * self.K_XZ).sum(dim=1))
        var_f_term2 = (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
        var_f = var_f_term1 + var_f_term2
        
        expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f

        # 2. Update alpha_lambda and beta_lambda using Eq. (1) and (2) [cite: 62, 64]
        self.alpha_lambda = self.nu_epsilon / 2.0 + 0.5
        self.beta_lambda = self.nu_epsilon / 2.0 + (0.5 / self.sigma_sq) * expected_sq_error

    def _update_q_r(self):
        """
        Updates the variational parameters for the global precision q(r).
        This corresponds to lines 10-12 in Algorithm 1. [cite: 146, 150]
        """
        # 1. Compute E_q(u)[u^T * K_ZZ^-1 * u] [cite: 148]
        # Using formula: Tr(A*Sigma) + mu^T*A*mu [cite: 122]
        trace_term = torch.trace(self.K_ZZ_inv @ self.S_u)
        mean_term = self.m_u.T @ self.K_ZZ_inv @ self.m_u
        expected_u_quadratic_form = trace_term + mean_term

        # 2. Update alpha_r and beta_r using Eq. (3) and (4) [cite: 67, 68]
        self.alpha_r = self.nu_f / 2.0 + self.M / 2.0
        self.beta_r = self.nu_f / 2.0 + 0.5 * expected_u_quadratic_form.squeeze()

    def _update_q_u(self):
        """
        Updates the variational parameters for q(u).
        This corresponds to lines 15-17 in Algorithm 1. [cite: 159, 162]
        """
        # 1. Compute required expectations E[r] and E[lambda_i] [cite: 160]
        # E[X] = alpha / beta for X ~ Gamma(alpha, beta) [cite: 126]
        expected_r = self.alpha_r / self.beta_r
        expected_lambda = self.alpha_lambda / self.beta_lambda
        
        # 2. Update S_u and m_u [cite: 106]
        K_ZZ_inv_T = self.K_ZZ_inv.T
        
        # Compute the precision matrix (S_u*)^-1
        # First part of the sum for the precision matrix
        precision_u_prior = expected_r * self.K_ZZ_inv
        
        # Second part of the sum (from the likelihood)
        expected_prec_lambda = self.sigma_sq * expected_lambda
        K_ZX = self.K_XZ.T
        # Efficiently compute sum over N of k_Z,i * k_i,Z
        A = K_ZX * expected_prec_lambda # Element-wise mult broadcasts lambda
        B = A @ self.K_XZ
        
        precision_u_lik = K_ZZ_inv_T @ B @ self.K_ZZ_inv
        
        precision_u = precision_u_prior + precision_u_lik
        
        # Updated S_u is the inverse of the precision matrix
        self.S_u = torch.inverse(precision_u + torch.eye(self.M) * 1e-6)

        # Compute the mean-related term `b` to find the new m_u
        b = K_ZZ_inv_T @ (K_ZX @ (expected_prec_lambda * self.y))
        self.m_u = (self.S_u @ b).unsqueeze(1)


    def fit(self, num_iterations=100, tol=1e-5):
        """
        Runs the CAVI algorithm until convergence. [cite: 132, 164]
        """
        print("Starting CAVI optimization...")
        for i in range(num_iterations):
            m_u_old = self.m_u.clone()
            
            # --- Perform CAVI updates in sequence ---
            # 1. Update local likelihood precisions q(lambda_i)
            self._update_q_lambda()
            
            # 2. Update global prior precision q(r)
            self._update_q_r()
            
            # 3. Update inducing point distribution q(u)
            self._update_q_u()
            
            # Check for convergence
            change = torch.norm(self.m_u - m_u_old) / torch.norm(m_u_old)
            print(f"Iteration {i+1}/{num_iterations}, Change in m_u: {change.item():.6f}")
            if change < tol:
                print(f"Convergence reached after {i+1} iterations.")
                break
        print("Optimization finished.")

# Example usage (requires data)
if __name__ == '__main__':
    # --- Create synthetic data for demonstration ---
    N_train = 100
    D_dim = 1
    X_train = torch.linspace(-5, 5, N_train).unsqueeze(1)
    # True function with some noise
    y_true = torch.sin(X_train) + torch.randn(N_train, 1) * 0.2
    # Add some outliers
    outlier_indices = [10, 20, 80]
    y_train = y_true.clone()
    y_train[outlier_indices] += torch.tensor([5.0, -4.0, 6.0]).unsqueeze(1)

    # --- Initialize and run the model ---
    model = TPRegressionCAVI(X_train, y_train, M=20, nu_f=5.0, nu_epsilon=5.0)
    model.fit(num_iterations=50)

    # After fitting, model.m_u, model.S_u, etc., contain the learned parameters.
    # A predict() function would use these to compute the predictive distribution
    # on new test points, as described in Section 7. [cite: 167]
# Out:
# Starting CAVI optimization...
# Iteration 1/50, Change in m_u: inf
# Iteration 2/50, Change in m_u: 2.148124
# Iteration 3/50, Change in m_u: 1.366527
# Iteration 4/50, Change in m_u: 0.687564
# Iteration 5/50, Change in m_u: 0.577397
# Iteration 6/50, Change in m_u: 3.158830
# Iteration 7/50, Change in m_u: 3.097112
# Iteration 8/50, Change in m_u: 0.717114
# Iteration 9/50, Change in m_u: 0.942664
# Iteration 10/50, Change in m_u: 0.338264
# Iteration 11/50, Change in m_u: 0.231058
# Iteration 12/50, Change in m_u: 0.440415
# Iteration 13/50, Change in m_u: 0.287278
# Iteration 14/50, Change in m_u: 0.273934
# Iteration 15/50, Change in m_u: 3.492574
# Iteration 16/50, Change in m_u: 0.933631
# Iteration 17/50, Change in m_u: 2.439029
# Iteration 18/50, Change in m_u: 0.978648
# Iteration 19/50, Change in m_u: 0.323734
# Iteration 20/50, Change in m_u: 0.701239
# Iteration 21/50, Change in m_u: 0.468833
# Iteration 22/50, Change in m_u: 1.404691
# Iteration 23/50, Change in m_u: 0.602685
# Iteration 24/50, Change in m_u: 0.574073
# Iteration 25/50, Change in m_u: 1.067827
# Iteration 26/50, Change in m_u: 1.093000
# Iteration 27/50, Change in m_u: 0.821987
# Iteration 28/50, Change in m_u: 2.393981
# Iteration 29/50, Change in m_u: 1.554713
# Iteration 30/50, Change in m_u: 0.530381
# Iteration 31/50, Change in m_u: 0.796148
# Iteration 32/50, Change in m_u: 0.430533
# Iteration 33/50, Change in m_u: 0.277945
# Iteration 34/50, Change in m_u: 1.121485
# Iteration 35/50, Change in m_u: 0.655005
# Iteration 36/50, Change in m_u: 0.218842
# Iteration 37/50, Change in m_u: 0.196433
# Iteration 38/50, Change in m_u: 0.440817
# Iteration 39/50, Change in m_u: 0.711830
# Iteration 40/50, Change in m_u: 0.564195
# Iteration 41/50, Change in m_u: 0.307962
# Iteration 42/50, Change in m_u: 0.425026
# Iteration 43/50, Change in m_u: 1.485050
# Iteration 44/50, Change in m_u: 1.162221
# Iteration 45/50, Change in m_u: 1.045810
# Iteration 46/50, Change in m_u: 0.848069
# Iteration 47/50, Change in m_u: 0.762228
# Iteration 48/50, Change in m_u: 0.442142
# Iteration 49/50, Change in m_u: 0.655663
# Iteration 50/50, Change in m_u: 5.874900
# Optimization finished.
