# %% [markdown]
# # MLP Evaluation on Regression Tasks
#
# This notebook evaluates a Multi-Layer Perceptron (MLP) model built with PyTorch on various regression datasets.
# The evaluation metric used is Root Mean Squared Error (RMSE).

# %% [markdown]
# ## 1. Define the MLP Model

# %% [markdown]
# ## 2. Data Loading Function

# %% [markdown]
# ## 3. Training and Evaluation Loop

# %%
# Out:
# --- Evaluating dataset: Bike ---
#   Split 0: RMSE = 1.0524
#   Split 1: RMSE = 0.8845
#   Split 0: RMSE = 1.0524
#   Split 1: RMSE = 0.8845
#   Split 2: RMSE = 0.7952
#   Split 3: RMSE = 1.0293
#   Split 4: RMSE = 0.8964
#   Split 2: RMSE = 0.7952
#   Split 3: RMSE = 1.0293
#   Split 4: RMSE = 0.8964
#   Split 5: RMSE = 1.1098
#   Split 6: RMSE = 0.7898
#   Split 7: RMSE = 0.8217
#   Split 5: RMSE = 1.1098
#   Split 6: RMSE = 0.7898
#   Split 7: RMSE = 0.8217
#   Split 8: RMSE = 0.8735
#   Split 9: RMSE = 0.9537
#   => Average RMSE for Bike: 0.9206 ± 0.1062
# --- Evaluating dataset: Concrete ---
#   Split 8: RMSE = 0.8735
#   Split 9: RMSE = 0.9537
#   => Average RMSE for Bike: 0.9206 ± 0.1062
# --- Evaluating dataset: Concrete ---
#   Split 0: RMSE = 0.4372
#   Split 1: RMSE = 0.4468
#   Split 0: RMSE = 0.4372
#   Split 1: RMSE = 0.4468
#   Split 2: RMSE = 0.5408
#   Split 3: RMSE = 0.5653
#   Split 2: RMSE = 0.5408
#   Split 3: RMSE = 0.5653
#   Split 4: RMSE = 0.5215
# ...

# %% [markdown]
# ## 4. Display Results

# %%
# Out:
# --- Overall Results (RMSE) ---
#             Bike   Concrete   Diabetes        ELE        MPG  Machine_CPU  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000    10.000000
# mean    0.920641   0.506529   1.100080   0.554624   0.361550     0.252787
# std     0.111945   0.062323   0.404595   0.085818   0.070853     0.125193
# min     0.789808   0.434426   0.699378   0.430473   0.238493     0.133780
# 25%     0.834676   0.449359   0.772188   0.478931   0.321494     0.182826
# 50%     0.890453   0.502891   1.034448   0.583311   0.377055     0.193127
# 75%     1.010412   0.559158   1.270345   0.629805   0.391140     0.270631
# max     1.109779   0.591809   1.998220   0.647134   0.465193     0.510504
#
#             Neal  Neal_XOutlier
# count  10.000000      10.000000
# mean    1.522390       1.214168
# std     0.245535       0.125619
# min     1.143089       1.056721
# 25%     1.436051       1.142078
# 50%     1.501629       1.177579
# 75%     1.596443       1.288688
# ...
