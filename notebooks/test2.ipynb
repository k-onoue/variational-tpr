# %%
import torch

# A placeholder for a kernel function (e.g., RBF)
def rbf_kernel(X1, X2, lengthscale=1.0, variance=1.0):
    """
    Computes the RBF kernel matrix between two sets of points.
    """
    sqdist = torch.cdist(X1, X2, p=2).pow(2)
    return variance * torch.exp(-0.5 * sqdist / lengthscale**2)

class TPRegressionCAVI:
    """
    PyTorch implementation of CAVI for Student-t Process Regression
    with a Student-t Likelihood, based on the provided document.
    """
    def __init__(self, X, y, M=20, nu_f=5.0, nu_epsilon=5.0, sigma_sq=1.0):
        """
        Initializes the model and variational parameters. [cite: 133]

        Args:
            X (torch.Tensor): Training inputs (N x D).
            y (torch.Tensor): Training outputs (N x 1).
            M (int): Number of inducing points.
            nu_f (float): Degrees of freedom for the TP prior. [cite: 13]
            nu_epsilon (float): Degrees of freedom for the likelihood. [cite: 19]
            sigma_sq (float): Scale parameter for the likelihood noise. [cite: 19]
        """
        self.X = X
        self.y = y.squeeze()
        self.N, self.D = X.shape
        self.M = M

        # Initialize hyperparameters [cite: 133]
        self.nu_f = torch.tensor(nu_f)
        self.nu_epsilon = torch.tensor(nu_epsilon)
        self.sigma_sq = torch.tensor(sigma_sq)
        self.kernel = rbf_kernel

        # Initialize inducing points Z by selecting M random points from X
        indices = torch.randperm(self.N)[:self.M]
        self.Z = self.X[indices].clone()

        # Pre-compute kernel matrices
        self.K_ZZ = self.kernel(self.Z, self.Z) + torch.eye(self.M) * 1e-6
        self.K_ZZ_inv = torch.inverse(self.K_ZZ)
        self.K_XZ = self.kernel(self.X, self.Z)
        
        # --- Initialize Variational Parameters --- [cite: 133]
        # q(u) = N(m_u, S_u)
        self.m_u = torch.zeros(self.M, 1) # [cite: 47]
        self.S_u = torch.eye(self.M)       # [cite: 47]

        # q(r) = Gamma(alpha_r, beta_r)
        self.alpha_r = torch.tensor(1.0) # [cite: 49]
        self.beta_r = torch.tensor(1.0)  # [cite: 49]

        # q(lambda_i) = Gamma(alpha_lambda_i, beta_lambda_i)
        self.alpha_lambda = torch.ones(self.N) # [cite: 51]
        self.beta_lambda = torch.ones(self.N)  # [cite: 51]

    def _update_q_lambda(self):
        """
        Updates the variational parameters for q(lambda_i) for all i=1..N.
        This corresponds to lines 5-8 in Algorithm 1. [cite: 137, 143]
        """
        # 1. Compute expected squared error E_q[(y_i - f_i)^2] [cite: 141]
        # E_q[(y_i - f_i)^2] = (y_i - E[f_i])^2 + Var(f_i) [cite: 112]
        
        # Calculate E[f_i] = k_i,Z * K_ZZ^-1 * m_u [cite: 114]
        K_ZZ_inv_m_u = torch.linalg.solve(self.K_ZZ, self.m_u)
        expected_f_mean = self.K_XZ @ K_ZZ_inv_m_u

        # Calculate Var(f_i) [cite: 116, 118]
        # We need E[r^-1] = beta_r / (alpha_r - 1) for alpha_r > 1 [cite: 119]
        if self.alpha_r > 1:
            expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
        else:
            expected_r_inv = self.beta_r # Fallback for stability at initialization
        
        k_ii = torch.diag(self.kernel(self.X, self.X))
        K_XZ_K_ZZ_inv = self.K_XZ @ self.K_ZZ_inv
        
        var_f_term1 = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * self.K_XZ).sum(dim=1))
        var_f_term2 = (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
        var_f = var_f_term1 + var_f_term2
        
        expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f

        # 2. Update alpha_lambda and beta_lambda using Eq. (1) and (2) [cite: 62, 64]
        self.alpha_lambda = self.nu_epsilon / 2.0 + 0.5
        self.beta_lambda = self.nu_epsilon / 2.0 + (0.5 / self.sigma_sq) * expected_sq_error

    def _update_q_r(self):
        """
        Updates the variational parameters for the global precision q(r).
        This corresponds to lines 10-12 in Algorithm 1. [cite: 146, 150]
        """
        # 1. Compute E_q(u)[u^T * K_ZZ^-1 * u] [cite: 148]
        # Using formula: Tr(A*Sigma) + mu^T*A*mu [cite: 122]
        trace_term = torch.trace(self.K_ZZ_inv @ self.S_u)
        mean_term = self.m_u.T @ self.K_ZZ_inv @ self.m_u
        expected_u_quadratic_form = trace_term + mean_term

        # 2. Update alpha_r and beta_r using Eq. (3) and (4) [cite: 67, 68]
        self.alpha_r = self.nu_f / 2.0 + self.M / 2.0
        self.beta_r = self.nu_f / 2.0 + 0.5 * expected_u_quadratic_form.squeeze()

    def _update_q_u(self):
        """
        Updates the variational parameters for q(u).
        This corresponds to lines 15-17 in Algorithm 1. [cite: 159, 162]
        """
        # 1. Compute required expectations E[r] and E[lambda_i] [cite: 160]
        # E[X] = alpha / beta for X ~ Gamma(alpha, beta) [cite: 126]
        expected_r = self.alpha_r / self.beta_r
        expected_lambda = self.alpha_lambda / self.beta_lambda
        
        # 2. Update S_u and m_u [cite: 106]
        K_ZZ_inv_T = self.K_ZZ_inv.T
        
        # Compute the precision matrix (S_u*)^-1
        # First part of the sum for the precision matrix
        precision_u_prior = expected_r * self.K_ZZ_inv
        
        # Second part of the sum (from the likelihood)
        expected_prec_lambda = self.sigma_sq * expected_lambda
        K_ZX = self.K_XZ.T
        # Efficiently compute sum over N of k_Z,i * k_i,Z
        A = K_ZX * expected_prec_lambda # Element-wise mult broadcasts lambda
        B = A @ self.K_XZ
        
        precision_u_lik = K_ZZ_inv_T @ B @ self.K_ZZ_inv
        
        precision_u = precision_u_prior + precision_u_lik
        
        # Updated S_u is the inverse of the precision matrix
        self.S_u = torch.inverse(precision_u + torch.eye(self.M) * 1e-6)

        # Compute the mean-related term `b` to find the new m_u
        b = K_ZZ_inv_T @ (K_ZX @ (expected_prec_lambda * self.y))
        self.m_u = (self.S_u @ b).unsqueeze(1)


    def fit(self, num_iterations=100, tol=1e-5):
        """
        Runs the CAVI algorithm until convergence. [cite: 132, 164]
        """
        print("Starting CAVI optimization...")
        for i in range(num_iterations):
            m_u_old = self.m_u.clone()
            
            # --- Perform CAVI updates in sequence ---
            # 1. Update local likelihood precisions q(lambda_i)
            self._update_q_lambda()
            
            # 2. Update global prior precision q(r)
            self._update_q_r()
            
            # 3. Update inducing point distribution q(u)
            self._update_q_u()
            
            # Check for convergence
            change = torch.norm(self.m_u - m_u_old) / torch.norm(m_u_old)
            print(f"Iteration {i+1}/{num_iterations}, Change in m_u: {change.item():.6f}")
            if change < tol:
                print(f"Convergence reached after {i+1} iterations.")
                break
        print("Optimization finished.")

# Example usage (requires data)
if __name__ == '__main__':
    # --- Create synthetic data for demonstration ---
    N_train = 100
    D_dim = 1
    X_train = torch.linspace(-5, 5, N_train).unsqueeze(1)
    # True function with some noise
    y_true = torch.sin(X_train) + torch.randn(N_train, 1) * 0.2
    # Add some outliers
    outlier_indices = [10, 20, 80]
    y_train = y_true.clone()
    y_train[outlier_indices] += torch.tensor([5.0, -4.0, 6.0]).unsqueeze(1)

    # --- Initialize and run the model ---
    model = TPRegressionCAVI(X_train, y_train, M=20, nu_f=5.0, nu_epsilon=5.0)
    model.fit(num_iterations=500)

    # After fitting, model.m_u, model.S_u, etc., contain the learned parameters.
    # A predict() function would use these to compute the predictive distribution
    # on new test points, as described in Section 7. [cite: 167]
# Out:
# Starting CAVI optimization...
# Iteration 1/500, Change in m_u: inf
# Iteration 2/500, Change in m_u: 2.279843
# Iteration 3/500, Change in m_u: 1.057530
# Iteration 4/500, Change in m_u: 9.346714
# Iteration 5/500, Change in m_u: 1.169636
# Iteration 6/500, Change in m_u: 1.213006
# Iteration 7/500, Change in m_u: 1.413294
# Iteration 8/500, Change in m_u: 456.308014
# Iteration 9/500, Change in m_u: 1.003176
# Iteration 10/500, Change in m_u: 0.909380
# Iteration 11/500, Change in m_u: 2.477642
# Iteration 12/500, Change in m_u: 1.030133
# Iteration 13/500, Change in m_u: 1.264856
# Iteration 14/500, Change in m_u: 6.129253
# Iteration 15/500, Change in m_u: 1.017811
# Iteration 16/500, Change in m_u: 5.672445
# Iteration 17/500, Change in m_u: 1.112779
# Iteration 18/500, Change in m_u: 0.564531
# Iteration 19/500, Change in m_u: 0.983023
# Iteration 20/500, Change in m_u: 2.052995
# Iteration 21/500, Change in m_u: 1.091069
# Iteration 22/500, Change in m_u: 0.139272
# Iteration 23/500, Change in m_u: 1.778795
# Iteration 24/500, Change in m_u: 0.823246
# Iteration 25/500, Change in m_u: 0.832038
# Iteration 26/500, Change in m_u: 0.172887
# Iteration 27/500, Change in m_u: 0.265683
# Iteration 28/500, Change in m_u: 0.175292
# Iteration 29/500, Change in m_u: 3.170344
# Iteration 30/500, Change in m_u: 0.856406
# Iteration 31/500, Change in m_u: 0.365336
# Iteration 32/500, Change in m_u: 0.283488
# Iteration 33/500, Change in m_u: 0.327232
# Iteration 34/500, Change in m_u: 4.086135
# Iteration 35/500, Change in m_u: 1.318820
# Iteration 36/500, Change in m_u: 0.471014
# Iteration 37/500, Change in m_u: 0.473462
# Iteration 38/500, Change in m_u: 4.470036
# Iteration 39/500, Change in m_u: 1.038858
# Iteration 40/500, Change in m_u: 1.261069
# Iteration 41/500, Change in m_u: 0.718297
# Iteration 42/500, Change in m_u: 0.461165
# Iteration 43/500, Change in m_u: 0.954060
# Iteration 44/500, Change in m_u: 0.940233
# Iteration 45/500, Change in m_u: 25.050056
# Iteration 46/500, Change in m_u: 2.158707
# Iteration 47/500, Change in m_u: 1.134317
# Iteration 48/500, Change in m_u: 1.167797
# Iteration 49/500, Change in m_u: 1.078098
# Iteration 50/500, Change in m_u: 1.110951
# Iteration 51/500, Change in m_u: 1.177196
# Iteration 52/500, Change in m_u: 0.685946
# Iteration 53/500, Change in m_u: 1.726890
# Iteration 54/500, Change in m_u: 1.422860
# Iteration 55/500, Change in m_u: 0.625976
# Iteration 56/500, Change in m_u: 0.644240
# Iteration 57/500, Change in m_u: 1.136025
# Iteration 58/500, Change in m_u: 0.945351
# Iteration 59/500, Change in m_u: 29.937931
# Iteration 60/500, Change in m_u: 0.844001
# Iteration 61/500, Change in m_u: 1.087932
# Iteration 62/500, Change in m_u: 1.292410
# Iteration 63/500, Change in m_u: 0.643508
# Iteration 64/500, Change in m_u: 0.369633
# Iteration 65/500, Change in m_u: 0.643876
# Iteration 66/500, Change in m_u: 0.366050
# Iteration 67/500, Change in m_u: 0.679018
# Iteration 68/500, Change in m_u: 0.585977
# Iteration 69/500, Change in m_u: 0.672446
# Iteration 70/500, Change in m_u: 0.498959
# Iteration 71/500, Change in m_u: 0.422693
# Iteration 72/500, Change in m_u: 0.921310
# Iteration 73/500, Change in m_u: 4.923949
# Iteration 74/500, Change in m_u: 0.967984
# Iteration 75/500, Change in m_u: 1.385654
# Iteration 76/500, Change in m_u: 4.723382
# Iteration 77/500, Change in m_u: 0.871976
# Iteration 78/500, Change in m_u: 5.333362
# Iteration 79/500, Change in m_u: 0.289687
# Iteration 80/500, Change in m_u: 1.024467
# Iteration 81/500, Change in m_u: 0.876599
# Iteration 82/500, Change in m_u: 0.194858
# Iteration 83/500, Change in m_u: 0.224794
# Iteration 84/500, Change in m_u: 0.168816
# Iteration 85/500, Change in m_u: 0.621205
# Iteration 86/500, Change in m_u: 0.690349
# Iteration 87/500, Change in m_u: 0.351659
# Iteration 88/500, Change in m_u: 0.193797
# Iteration 89/500, Change in m_u: 0.312290
# Iteration 90/500, Change in m_u: 1.552815
# Iteration 91/500, Change in m_u: 0.520279
# Iteration 92/500, Change in m_u: 0.491059
# Iteration 93/500, Change in m_u: 0.448975
# Iteration 94/500, Change in m_u: 1.174322
# Iteration 95/500, Change in m_u: 0.565505
# Iteration 96/500, Change in m_u: 0.512335
# Iteration 97/500, Change in m_u: 1.152706
# Iteration 98/500, Change in m_u: 0.879324
# Iteration 99/500, Change in m_u: 0.375520
# Iteration 100/500, Change in m_u: 0.383870
# Iteration 101/500, Change in m_u: 0.693193
# Iteration 102/500, Change in m_u: 0.401231
# Iteration 103/500, Change in m_u: 3.123012
# Iteration 104/500, Change in m_u: 1.104670
# Iteration 105/500, Change in m_u: 1.351393
# Iteration 106/500, Change in m_u: 1.080836
# Iteration 107/500, Change in m_u: 1.473352
# Iteration 108/500, Change in m_u: 0.434189
# Iteration 109/500, Change in m_u: 0.298803
# Iteration 110/500, Change in m_u: 0.253505
# Iteration 111/500, Change in m_u: 0.365988
# Iteration 112/500, Change in m_u: 0.447336
# Iteration 113/500, Change in m_u: 0.843416
# Iteration 114/500, Change in m_u: 0.772482
# Iteration 115/500, Change in m_u: 1.786899
# Iteration 116/500, Change in m_u: 1.962533
# Iteration 117/500, Change in m_u: 1.036315
# Iteration 118/500, Change in m_u: 0.541454
# Iteration 119/500, Change in m_u: 2.021197
# Iteration 120/500, Change in m_u: 0.866444
# Iteration 121/500, Change in m_u: 0.104720
# Iteration 122/500, Change in m_u: 2.575112
# Iteration 123/500, Change in m_u: 0.833994
# Iteration 124/500, Change in m_u: 3.964415
# Iteration 125/500, Change in m_u: 0.648441
# Iteration 126/500, Change in m_u: 0.935518
# Iteration 127/500, Change in m_u: 0.743150
# Iteration 128/500, Change in m_u: 1.111015
# Iteration 129/500, Change in m_u: 0.518377
# Iteration 130/500, Change in m_u: 2.552768
# Iteration 131/500, Change in m_u: 0.713148
# Iteration 132/500, Change in m_u: 12.416628
# Iteration 133/500, Change in m_u: 3.590235
# Iteration 134/500, Change in m_u: 0.975805
# Iteration 135/500, Change in m_u: 0.907838
# Iteration 136/500, Change in m_u: 0.987542
# Iteration 137/500, Change in m_u: 0.531357
# Iteration 138/500, Change in m_u: 0.693573
# Iteration 139/500, Change in m_u: 0.248580
# Iteration 140/500, Change in m_u: 0.091979
# Iteration 141/500, Change in m_u: 0.417505
# Iteration 142/500, Change in m_u: 2.292368
# Iteration 143/500, Change in m_u: 0.946669
# Iteration 144/500, Change in m_u: 0.479000
# Iteration 145/500, Change in m_u: 2.058005
# Iteration 146/500, Change in m_u: 1.557273
# Iteration 147/500, Change in m_u: 0.675395
# Iteration 148/500, Change in m_u: 0.776233
# Iteration 149/500, Change in m_u: 0.584072
# Iteration 150/500, Change in m_u: 4.049267
# Iteration 151/500, Change in m_u: 0.975451
# Iteration 152/500, Change in m_u: 0.684812
# Iteration 153/500, Change in m_u: 1.148679
# Iteration 154/500, Change in m_u: 0.309207
# Iteration 155/500, Change in m_u: 1.012094
# Iteration 156/500, Change in m_u: 0.955162
# Iteration 157/500, Change in m_u: 0.595294
# Iteration 158/500, Change in m_u: 30.666279
# Iteration 159/500, Change in m_u: 0.998515
# Iteration 160/500, Change in m_u: 0.873138
# Iteration 161/500, Change in m_u: 0.841002
# Iteration 162/500, Change in m_u: 0.691324
# Iteration 163/500, Change in m_u: 6.203571
# Iteration 164/500, Change in m_u: 0.716523
# Iteration 165/500, Change in m_u: 0.313085
# Iteration 166/500, Change in m_u: 0.648582
# Iteration 167/500, Change in m_u: 0.394402
# Iteration 168/500, Change in m_u: 7.574148
# Iteration 169/500, Change in m_u: 0.898196
# Iteration 170/500, Change in m_u: 0.680109
# Iteration 171/500, Change in m_u: 0.638163
# Iteration 172/500, Change in m_u: 1.958425
# Iteration 173/500, Change in m_u: 1.268073
# Iteration 174/500, Change in m_u: 0.590445
# Iteration 175/500, Change in m_u: 1.253289
# Iteration 176/500, Change in m_u: 0.885038
# Iteration 177/500, Change in m_u: 0.855409
# Iteration 178/500, Change in m_u: 0.600216
# Iteration 179/500, Change in m_u: 0.335128
# Iteration 180/500, Change in m_u: 0.377610
# Iteration 181/500, Change in m_u: 0.394347
# Iteration 182/500, Change in m_u: 3.058661
# Iteration 183/500, Change in m_u: 1.165294
# Iteration 184/500, Change in m_u: 0.714361
# Iteration 185/500, Change in m_u: 0.603517
# Iteration 186/500, Change in m_u: 1.654647
# Iteration 187/500, Change in m_u: 0.665979
# Iteration 188/500, Change in m_u: 0.237979
# Iteration 189/500, Change in m_u: 1.788284
# Iteration 190/500, Change in m_u: 0.798629
# Iteration 191/500, Change in m_u: 0.748604
# Iteration 192/500, Change in m_u: 0.781939
# Iteration 193/500, Change in m_u: 0.447779
# Iteration 194/500, Change in m_u: 1.095612
# Iteration 195/500, Change in m_u: 0.499188
# Iteration 196/500, Change in m_u: 3.521667
# Iteration 197/500, Change in m_u: 0.904166
# Iteration 198/500, Change in m_u: 0.566880
# Iteration 199/500, Change in m_u: 6.565600
# Iteration 200/500, Change in m_u: 1.066827
# Iteration 201/500, Change in m_u: 0.859821
# Iteration 202/500, Change in m_u: 0.724959
# Iteration 203/500, Change in m_u: 0.300434
# Iteration 204/500, Change in m_u: 0.390972
# Iteration 205/500, Change in m_u: 0.130003
# Iteration 206/500, Change in m_u: 1.647581
# Iteration 207/500, Change in m_u: 1.111428
# Iteration 208/500, Change in m_u: 1.698899
# Iteration 209/500, Change in m_u: 0.876925
# Iteration 210/500, Change in m_u: 0.256508
# Iteration 211/500, Change in m_u: 0.523091
# Iteration 212/500, Change in m_u: 0.678326
# Iteration 213/500, Change in m_u: 0.419505
# Iteration 214/500, Change in m_u: 0.357539
# Iteration 215/500, Change in m_u: 4.509418
# Iteration 216/500, Change in m_u: 1.003394
# Iteration 217/500, Change in m_u: 0.342603
# Iteration 218/500, Change in m_u: 0.345675
# Iteration 219/500, Change in m_u: 0.375305
# Iteration 220/500, Change in m_u: 0.351431
# Iteration 221/500, Change in m_u: 0.529200
# Iteration 222/500, Change in m_u: 2.400140
# Iteration 223/500, Change in m_u: 1.354905
# Iteration 224/500, Change in m_u: 0.860433
# Iteration 225/500, Change in m_u: 0.265495
# Iteration 226/500, Change in m_u: 1.239016
# Iteration 227/500, Change in m_u: 0.588124
# Iteration 228/500, Change in m_u: 5.638433
# Iteration 229/500, Change in m_u: 0.988461
# Iteration 230/500, Change in m_u: 0.682520
# Iteration 231/500, Change in m_u: 0.371349
# Iteration 232/500, Change in m_u: 122.758507
# Iteration 233/500, Change in m_u: 1.002922
# Iteration 234/500, Change in m_u: 2.629016
# Iteration 235/500, Change in m_u: 4.045133
# Iteration 236/500, Change in m_u: 0.808455
# Iteration 237/500, Change in m_u: 1.378800
# Iteration 238/500, Change in m_u: 0.883799
# Iteration 239/500, Change in m_u: 1.401167
# Iteration 240/500, Change in m_u: 0.792503
# Iteration 241/500, Change in m_u: 0.630202
# Iteration 242/500, Change in m_u: 1.201822
# Iteration 243/500, Change in m_u: 2.898606
# Iteration 244/500, Change in m_u: 5.658169
# Iteration 245/500, Change in m_u: 0.993764
# Iteration 246/500, Change in m_u: 0.631105
# Iteration 247/500, Change in m_u: 0.837142
# Iteration 248/500, Change in m_u: 3.153904
# Iteration 249/500, Change in m_u: 1.017815
# Iteration 250/500, Change in m_u: 0.566084
# Iteration 251/500, Change in m_u: 1.892063
# Iteration 252/500, Change in m_u: 0.940294
# Iteration 253/500, Change in m_u: 0.745168
# Iteration 254/500, Change in m_u: 0.636479
# Iteration 255/500, Change in m_u: 1.044981
# Iteration 256/500, Change in m_u: 0.849083
# Iteration 257/500, Change in m_u: 4.633572
# Iteration 258/500, Change in m_u: 1.112381
# Iteration 259/500, Change in m_u: 0.434377
# Iteration 260/500, Change in m_u: 1.398332
# Iteration 261/500, Change in m_u: 21.995678
# Iteration 262/500, Change in m_u: 0.624187
# Iteration 263/500, Change in m_u: 1.213991
# Iteration 264/500, Change in m_u: 2.379520
# Iteration 265/500, Change in m_u: 0.950858
# Iteration 266/500, Change in m_u: 6.504982
# Iteration 267/500, Change in m_u: 0.917062
# Iteration 268/500, Change in m_u: 1.820533
# Iteration 269/500, Change in m_u: 0.962910
# Iteration 270/500, Change in m_u: 1.310823
# Iteration 271/500, Change in m_u: 0.339112
# Iteration 272/500, Change in m_u: 0.544788
# Iteration 273/500, Change in m_u: 1.352748
# Iteration 274/500, Change in m_u: 1.481712
# Iteration 275/500, Change in m_u: 0.771028
# Iteration 276/500, Change in m_u: 1.560141
# Iteration 277/500, Change in m_u: 0.894098
# Iteration 278/500, Change in m_u: 0.356236
# Iteration 279/500, Change in m_u: 0.680804
# Iteration 280/500, Change in m_u: 0.438255
# Iteration 281/500, Change in m_u: 0.302953
# Iteration 282/500, Change in m_u: 1.021873
# Iteration 283/500, Change in m_u: 1.845525
# Iteration 284/500, Change in m_u: 0.836231
# Iteration 285/500, Change in m_u: 2.656874
# Iteration 286/500, Change in m_u: 1.049104
# Iteration 287/500, Change in m_u: 0.855540
# Iteration 288/500, Change in m_u: 0.593738
# Iteration 289/500, Change in m_u: 0.898639
# Iteration 290/500, Change in m_u: 0.559849
# Iteration 291/500, Change in m_u: 2.868225
# Iteration 292/500, Change in m_u: 2.346641
# Iteration 293/500, Change in m_u: 0.858107
# Iteration 294/500, Change in m_u: 1.013445
# Iteration 295/500, Change in m_u: 0.541564
# Iteration 296/500, Change in m_u: 0.689435
# Iteration 297/500, Change in m_u: 0.756803
# Iteration 298/500, Change in m_u: 0.314847
# Iteration 299/500, Change in m_u: 0.541767
# Iteration 300/500, Change in m_u: 1.036911
# Iteration 301/500, Change in m_u: 0.375343
# Iteration 302/500, Change in m_u: 0.748528
# Iteration 303/500, Change in m_u: 0.369534
# Iteration 304/500, Change in m_u: 0.556683
# Iteration 305/500, Change in m_u: 0.665370
# Iteration 306/500, Change in m_u: 0.589308
# Iteration 307/500, Change in m_u: 0.791784
# Iteration 308/500, Change in m_u: 3.214959
# Iteration 309/500, Change in m_u: 1.276819
# Iteration 310/500, Change in m_u: 0.857426
# Iteration 311/500, Change in m_u: 1.130564
# Iteration 312/500, Change in m_u: 0.929530
# Iteration 313/500, Change in m_u: 0.655560
# Iteration 314/500, Change in m_u: 0.343546
# Iteration 315/500, Change in m_u: 0.376072
# Iteration 316/500, Change in m_u: 0.547310
# Iteration 317/500, Change in m_u: 7.252887
# Iteration 318/500, Change in m_u: 0.753667
# Iteration 319/500, Change in m_u: 0.614706
# Iteration 320/500, Change in m_u: 0.970884
# Iteration 321/500, Change in m_u: 0.346464
# Iteration 322/500, Change in m_u: 0.162422
# Iteration 323/500, Change in m_u: 0.539938
# Iteration 324/500, Change in m_u: 0.409955
# Iteration 325/500, Change in m_u: 2.627741
# Iteration 326/500, Change in m_u: 1.844073
# Iteration 327/500, Change in m_u: 1.589598
# Iteration 328/500, Change in m_u: 0.570828
# Iteration 329/500, Change in m_u: 0.259944
# Iteration 330/500, Change in m_u: 1.496594
# Iteration 331/500, Change in m_u: 1.281408
# Iteration 332/500, Change in m_u: 0.718277
# Iteration 333/500, Change in m_u: 1.104778
# Iteration 334/500, Change in m_u: 1.840211
# Iteration 335/500, Change in m_u: 1.160814
# Iteration 336/500, Change in m_u: 0.167580
# Iteration 337/500, Change in m_u: 3.193687
# Iteration 338/500, Change in m_u: 0.975874
# Iteration 339/500, Change in m_u: 0.788476
# Iteration 340/500, Change in m_u: 2.754158
# Iteration 341/500, Change in m_u: 0.423957
# Iteration 342/500, Change in m_u: 0.747849
# Iteration 343/500, Change in m_u: 0.801190
# Iteration 344/500, Change in m_u: 1.370311
# Iteration 345/500, Change in m_u: 1.008585
# Iteration 346/500, Change in m_u: 0.613085
# Iteration 347/500, Change in m_u: 0.660334
# Iteration 348/500, Change in m_u: 0.657078
# Iteration 349/500, Change in m_u: 0.812458
# Iteration 350/500, Change in m_u: 0.585469
# Iteration 351/500, Change in m_u: 0.108722
# Iteration 352/500, Change in m_u: 0.396429
# Iteration 353/500, Change in m_u: 3.628484
# Iteration 354/500, Change in m_u: 0.712216
# Iteration 355/500, Change in m_u: 4.527734
# Iteration 356/500, Change in m_u: 1.194557
# Iteration 357/500, Change in m_u: 1.151822
# Iteration 358/500, Change in m_u: 0.262340
# Iteration 359/500, Change in m_u: 0.495162
# Iteration 360/500, Change in m_u: 1.166759
# Iteration 361/500, Change in m_u: 0.970814
# Iteration 362/500, Change in m_u: 0.861010
# Iteration 363/500, Change in m_u: 0.259853
# Iteration 364/500, Change in m_u: 1.327894
# Iteration 365/500, Change in m_u: 0.702679
# Iteration 366/500, Change in m_u: 5.412155
# Iteration 367/500, Change in m_u: 1.087291
# Iteration 368/500, Change in m_u: 1.091158
# Iteration 369/500, Change in m_u: 0.528987
# Iteration 370/500, Change in m_u: 6.011604
# Iteration 371/500, Change in m_u: 2.415406
# Iteration 372/500, Change in m_u: 1.002568
# Iteration 373/500, Change in m_u: 1.169837
# Iteration 374/500, Change in m_u: 0.601119
# Iteration 375/500, Change in m_u: 17.739807
# Iteration 376/500, Change in m_u: 42.518177
# Iteration 377/500, Change in m_u: 0.995154
# Iteration 378/500, Change in m_u: 6.783481
# Iteration 379/500, Change in m_u: 1.154061
# Iteration 380/500, Change in m_u: 6.464567
# Iteration 381/500, Change in m_u: 0.972580
# Iteration 382/500, Change in m_u: 3.540167
# Iteration 383/500, Change in m_u: 1.150392
# Iteration 384/500, Change in m_u: 0.942405
# Iteration 385/500, Change in m_u: 2.711254
# Iteration 386/500, Change in m_u: 0.940055
# Iteration 387/500, Change in m_u: 0.414098
# Iteration 388/500, Change in m_u: 0.959875
# Iteration 389/500, Change in m_u: 0.437126
# Iteration 390/500, Change in m_u: 0.207047
# Iteration 391/500, Change in m_u: 0.688814
# Iteration 392/500, Change in m_u: 1.033133
# Iteration 393/500, Change in m_u: 0.615233
# Iteration 394/500, Change in m_u: 0.583345
# Iteration 395/500, Change in m_u: 2.206313
# Iteration 396/500, Change in m_u: 0.859884
# Iteration 397/500, Change in m_u: 0.364332
# Iteration 398/500, Change in m_u: 0.365046
# Iteration 399/500, Change in m_u: 0.353204
# Iteration 400/500, Change in m_u: 2.052584
# Iteration 401/500, Change in m_u: 1.211330
# Iteration 402/500, Change in m_u: 0.738667
# Iteration 403/500, Change in m_u: 1.376399
# Iteration 404/500, Change in m_u: 0.425035
# Iteration 405/500, Change in m_u: 21.487900
# Iteration 406/500, Change in m_u: 0.688965
# Iteration 407/500, Change in m_u: 11.848695
# Iteration 408/500, Change in m_u: 0.978968
# Iteration 409/500, Change in m_u: 2.388668
# Iteration 410/500, Change in m_u: 0.998413
# Iteration 411/500, Change in m_u: 1.166557
# Iteration 412/500, Change in m_u: 0.781996
# Iteration 413/500, Change in m_u: 3.812015
# Iteration 414/500, Change in m_u: 0.940631
# Iteration 415/500, Change in m_u: 1.462256
# Iteration 416/500, Change in m_u: 0.953254
# Iteration 417/500, Change in m_u: 1.497588
# Iteration 418/500, Change in m_u: 0.743790
# Iteration 419/500, Change in m_u: 15.038004
# Iteration 420/500, Change in m_u: 7.921209
# Iteration 421/500, Change in m_u: 0.898400
# Iteration 422/500, Change in m_u: 0.783942
# Iteration 423/500, Change in m_u: 0.981757
# Iteration 424/500, Change in m_u: 5.110220
# Iteration 425/500, Change in m_u: 1.071690
# Iteration 426/500, Change in m_u: 0.579151
# Iteration 427/500, Change in m_u: 0.358909
# Iteration 428/500, Change in m_u: 0.823123
# Iteration 429/500, Change in m_u: 0.611485
# Iteration 430/500, Change in m_u: 1.129963
# Iteration 431/500, Change in m_u: 1.403617
# Iteration 432/500, Change in m_u: 0.428862
# Iteration 433/500, Change in m_u: 0.531942
# Iteration 434/500, Change in m_u: 0.696351
# Iteration 435/500, Change in m_u: 0.272182
# Iteration 436/500, Change in m_u: 1.615395
# Iteration 437/500, Change in m_u: 1.892981
# Iteration 438/500, Change in m_u: 1.164871
# Iteration 439/500, Change in m_u: 0.910112
# Iteration 440/500, Change in m_u: 0.729007
# Iteration 441/500, Change in m_u: 0.565876
# Iteration 442/500, Change in m_u: 0.704797
# Iteration 443/500, Change in m_u: 0.921177
# Iteration 444/500, Change in m_u: 1.839421
# Iteration 445/500, Change in m_u: 0.539446
# Iteration 446/500, Change in m_u: 0.418109
# Iteration 447/500, Change in m_u: 0.258906
# Iteration 448/500, Change in m_u: 0.371242
# Iteration 449/500, Change in m_u: 0.415655
# Iteration 450/500, Change in m_u: 0.276263
# Iteration 451/500, Change in m_u: 0.612881
# Iteration 452/500, Change in m_u: 1.516989
# Iteration 453/500, Change in m_u: 1.358208
# Iteration 454/500, Change in m_u: 0.609500
# Iteration 455/500, Change in m_u: 0.486550
# Iteration 456/500, Change in m_u: 1.574157
# Iteration 457/500, Change in m_u: 0.706302
# Iteration 458/500, Change in m_u: 8.814946
# Iteration 459/500, Change in m_u: 1.668328
# Iteration 460/500, Change in m_u: 1.058468
# Iteration 461/500, Change in m_u: 0.826770
# Iteration 462/500, Change in m_u: 1.146500
# Iteration 463/500, Change in m_u: 0.667690
# Iteration 464/500, Change in m_u: 0.558815
# Iteration 465/500, Change in m_u: 0.577077
# Iteration 466/500, Change in m_u: 1.219769
# Iteration 467/500, Change in m_u: 1.263027
# Iteration 468/500, Change in m_u: 1.113569
# Iteration 469/500, Change in m_u: 3.973347
# Iteration 470/500, Change in m_u: 0.976447
# Iteration 471/500, Change in m_u: 0.986847
# Iteration 472/500, Change in m_u: 56.942532
# Iteration 473/500, Change in m_u: 1.455161
# Iteration 474/500, Change in m_u: 17.265741
# Iteration 475/500, Change in m_u: 0.524630
# Iteration 476/500, Change in m_u: 1.010369
# Iteration 477/500, Change in m_u: 3.532520
# Iteration 478/500, Change in m_u: 0.200756
# Iteration 479/500, Change in m_u: 0.714113
# Iteration 480/500, Change in m_u: 2.099667
# Iteration 481/500, Change in m_u: 371.936707
# Iteration 482/500, Change in m_u: 1.048509
# Iteration 483/500, Change in m_u: 4.278185
# Iteration 484/500, Change in m_u: 0.988951
# Iteration 485/500, Change in m_u: 1.998255
# Iteration 486/500, Change in m_u: 0.699471
# Iteration 487/500, Change in m_u: 7.485347
# Iteration 488/500, Change in m_u: 0.999546
# Iteration 489/500, Change in m_u: 1.510588
# Iteration 490/500, Change in m_u: 1.161133
# Iteration 491/500, Change in m_u: 1.387236
# Iteration 492/500, Change in m_u: 0.833504
# Iteration 493/500, Change in m_u: 1.552618
# Iteration 494/500, Change in m_u: 2.406470
# Iteration 495/500, Change in m_u: 0.707205
# Iteration 496/500, Change in m_u: 0.469992
# Iteration 497/500, Change in m_u: 0.943067
# Iteration 498/500, Change in m_u: 1.235522
# Iteration 499/500, Change in m_u: 0.436924
# Iteration 500/500, Change in m_u: 0.853878
# Optimization finished.

# %%
import torch
import torch.optim as optim

# A placeholder for a kernel function (e.g., RBF)
def rbf_kernel(X1, X2, lengthscale=1.0, variance=1.0):
    """
    Computes the RBF kernel matrix between two sets of points.
    """
    sqdist = torch.cdist(X1, X2, p=2).pow(2)
    return variance * torch.exp(-0.5 * sqdist / lengthscale**2)

class TPRegressionVariationalEM:
    """
    Implementation of Variational EM for Student-t Process Regression.
    - E-Step: CAVI updates for variational parameters.
    - M-Step: Gradient-based optimization of model hyperparameters.
    """
    def __init__(self, X, y, M=20):
        self.X = X
        self.y = y.squeeze()
        self.N, self.D = X.shape
        self.M = M

        # --- Initialize Hyperparameters to be Optimized (M-step) ---
        # These are now learnable parameters.
        self.log_nu_f = torch.nn.Parameter(torch.log(torch.tensor(5.0)))
        self.log_nu_epsilon = torch.nn.Parameter(torch.log(torch.tensor(5.0)))
        self.log_sigma_sq = torch.nn.Parameter(torch.log(torch.tensor(1.0)))
        self.log_kernel_lengthscale = torch.nn.Parameter(torch.tensor(0.0))
        self.log_kernel_variance = torch.nn.Parameter(torch.tensor(0.0))

        # --- Initialize Variational Parameters (E-step) ---
        indices = torch.randperm(self.N)[:self.M]
        self.Z = self.X[indices].clone()

        self.m_u = torch.zeros(self.M, 1)
        self.S_u = torch.eye(self.M)
        self.alpha_r = torch.tensor(1.0)
        self.beta_r = torch.tensor(1.0)
        self.alpha_lambda = torch.ones(self.N)
        self.beta_lambda = torch.ones(self.N)
        
        # Optimizer for the M-step
        self.optimizer = optim.Adam(
            [self.log_nu_f, self.log_nu_epsilon, self.log_sigma_sq,
             self.log_kernel_lengthscale, self.log_kernel_variance],
            lr=0.01
        )

    def _get_hyperparams(self):
        """Returns the exponentiated (positive) hyperparameters."""
        return {
            "nu_f": torch.exp(self.log_nu_f),
            "nu_epsilon": torch.exp(self.log_nu_epsilon),
            "sigma_sq": torch.exp(self.log_sigma_sq),
            "lengthscale": torch.exp(self.log_kernel_lengthscale),
            "variance": torch.exp(self.log_kernel_variance)
        }
            
    def _e_step(self, cavi_iterations=10):
        """Performs the CAVI updates for the variational parameters (E-Step)."""
        with torch.no_grad(): # No gradients needed for the E-step updates
            params = self._get_hyperparams()
            
            # --- Kernel matrices and Cholesky decomposition (do once per E-step) ---
            K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
            try:
                L_ZZ = torch.linalg.cholesky(K_ZZ)
            except torch.linalg.LinAlgError:
                print("Warning: K_ZZ became non-positive definite in E-step. Skipping update.")
                return

            K_XZ = rbf_kernel(self.X, self.Z, params['lengthscale'], params['variance'])
            K_ZX = K_XZ.T
            k_ii = torch.diag(rbf_kernel(self.X, self.X, params['lengthscale'], params['variance']))
            
            # --- Pre-calculate K_ZZ_inv for the CAVI loop ---
            K_ZZ_inv = torch.cholesky_inverse(L_ZZ)

            for _ in range(cavi_iterations):
                # --- Update q(lambda) ---
                K_ZZ_inv_m_u = K_ZZ_inv @ self.m_u
                expected_f_mean = K_XZ @ K_ZZ_inv_m_u
                
                if self.alpha_r > 1: expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
                else: expected_r_inv = self.beta_r
                
                K_XZ_K_ZZ_inv = K_XZ @ K_ZZ_inv
                var_f_term1 = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * K_XZ).sum(dim=1))
                var_f_term2 = (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
                var_f = var_f_term1 + var_f_term2
                
                expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f
                self.alpha_lambda.fill_(params['nu_epsilon'] / 2.0 + 0.5) # Use fill_ for in-place
                self.beta_lambda = params['nu_epsilon'] / 2.0 + (0.5 / params['sigma_sq']) * expected_sq_error

                # --- Update q(r) ---
                trace_term = torch.trace(K_ZZ_inv @ self.S_u)
                mean_term = self.m_u.T @ K_ZZ_inv @ self.m_u
                expected_u_quadratic_form = trace_term + mean_term
                
                self.alpha_r = params['nu_f'] / 2.0 + self.M / 2.0
                self.beta_r = params['nu_f'] / 2.0 + 0.5 * expected_u_quadratic_form.squeeze()

                # --- Update q(u) ---
                expected_r = self.alpha_r / self.beta_r
                expected_lambda = self.alpha_lambda / self.beta_lambda
                
                precision_u_prior = expected_r * K_ZZ_inv
                
                # 💡 [MODIFIED] Using the standard formula for the likelihood precision
                precision_u_lik = (1 / params['sigma_sq']) * (K_ZX * expected_lambda) @ K_XZ

                precision_u = precision_u_prior + precision_u_lik
                
                # Use Cholesky for stability
                try:
                    L_precision = torch.linalg.cholesky(precision_u + torch.eye(self.M) * 1e-6)
                    self.S_u = torch.cholesky_inverse(L_precision)
                except torch.linalg.LinAlgError:
                    print("Warning: precision_u became non-positive definite in E-step. Skipping q(u) update.")
                    continue # Skip this update and continue CAVI loop

                # 💡 [MODIFIED] Corresponding update for the mean 'm_u'
                b = (1 / params['sigma_sq']) * K_ZX @ (expected_lambda * self.y)
                self.m_u = (self.S_u @ b).unsqueeze(1)

    def _calculate_elbo(self):
        """
        Calculates the Evidence Lower Bound (ELBO) using Cholesky decomposition
        and the standard precision formula.
        """
        params = self._get_hyperparams()

        print(f"params: nu_f={params['nu_f']:.4f}, nu_epsilon={params['nu_epsilon']:.4f}, lengthscale={params['lengthscale']:.4f}, variance={params['variance']:.4f}, sigma_sq={params['sigma_sq']:.4f}")

        # --- Kernel matrices and their Cholesky decomposition ---
        K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
        K_XZ = rbf_kernel(self.X, self.Z, params['lengthscale'], params['variance'])
        k_ii = torch.diag(rbf_kernel(self.X, self.X, params['lengthscale'], params['variance']))

        try:
            L_ZZ = torch.linalg.cholesky(K_ZZ)
        except torch.linalg.LinAlgError:
            print("Error: K_ZZ is not positive definite. ELBO will be nan.")
            return torch.tensor(float('nan'))

        # --- 1. Expected Log-Likelihood term ---
        expected_log_lambda = torch.digamma(self.alpha_lambda) - torch.log(self.beta_lambda)
        expected_lambda = self.alpha_lambda / self.beta_lambda

        K_ZZ_inv_m_u = torch.cholesky_solve(self.m_u, L_ZZ)
        expected_f_mean = K_XZ @ K_ZZ_inv_m_u

        if self.alpha_r > 1: expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
        else: expected_r_inv = self.beta_r
        
        tmp = torch.cholesky_solve(K_XZ.T, L_ZZ)
        K_XZ_K_ZZ_inv = tmp.T
        
        var_f_term1 = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * K_XZ).sum(dim=1))
        var_f_term2 = (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
        var_f = var_f_term1 + var_f_term2
        
        expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f
        expected_log_lik = 0.5 * torch.sum(expected_log_lambda - torch.log(2 * torch.pi * params['sigma_sq']) - expected_lambda / params['sigma_sq'] * expected_sq_error)

        # --- 2. KL Divergence terms ---
        p_alpha_r, p_beta_r = params['nu_f'] / 2.0, params['nu_f'] / 2.0
        kl_r = (self.alpha_r - p_alpha_r) * torch.digamma(self.alpha_r) - torch.lgamma(self.alpha_r) + torch.lgamma(p_alpha_r) \
                + p_alpha_r * (torch.log(self.beta_r) - torch.log(p_beta_r)) + self.alpha_r * (p_beta_r - self.beta_r) / self.beta_r

        # Recalculate precision_u with the standard formula to get its Cholesky factor
        expected_r = self.alpha_r / self.beta_r
        K_ZX = K_XZ.T
        K_ZZ_inv = torch.cholesky_inverse(L_ZZ)
        
        precision_u_prior = expected_r * K_ZZ_inv
        
        # 💡 [MODIFIED] Using the standard formula for the likelihood precision
        precision_u_lik = (1 / params['sigma_sq']) * (K_ZX * expected_lambda) @ K_XZ
        
        precision_u = precision_u_prior + precision_u_lik

        try:
            L_precision = torch.linalg.cholesky(precision_u + torch.eye(self.M) * 1e-6)
        except torch.linalg.LinAlgError:
            print("Error: precision_u is not positive definite. ELBO will be nan.")
            return torch.tensor(float('nan'))

        # KL(q(u)||p(u|r)) using Cholesky factors
        log_det_S_u = -2 * torch.sum(torch.log(torch.diag(L_precision)))
        log_det_K_ZZ = 2 * torch.sum(torch.log(torch.diag(L_ZZ)))
        expected_log_r = torch.digamma(self.alpha_r) - torch.log(self.beta_r)
        
        kl_u_term1 = 0.5 * (-log_det_S_u - self.M * expected_log_r + log_det_K_ZZ)
        
        trace_term = torch.trace(K_ZZ_inv @ self.S_u)
        mean_term = self.m_u.T @ K_ZZ_inv @ self.m_u
        
        kl_u_term2 = 0.5 * expected_r * (trace_term + mean_term)
        kl_u = kl_u_term1 + kl_u_term2.squeeze() - 0.5 * self.M
        
        kl_u_r = kl_u + kl_r

        # KL(q(lambda_i)||p(lambda_i))
        p_alpha_lambda, p_beta_lambda = params['nu_epsilon'] / 2.0, params['nu_epsilon'] / 2.0
        kl_lambda = torch.sum((self.alpha_lambda - p_alpha_lambda) * torch.digamma(self.alpha_lambda) \
                    - torch.lgamma(self.alpha_lambda) + torch.lgamma(p_alpha_lambda) \
                    + p_alpha_lambda * (torch.log(self.beta_lambda) - torch.log(p_beta_lambda)) \
                    + self.alpha_lambda * (p_beta_lambda - self.beta_r) / self.beta_lambda)
        
        print(f"term1: {expected_log_lik.item():.4f}, term2: {kl_u_r.item():.4f}, term3: {kl_lambda.item():.4f}")

        elbo = expected_log_lik - kl_u_r - kl_lambda
        
        if torch.isnan(elbo) or torch.isinf(elbo):
            print("Warning: ELBO is NaN or Inf.")
                
        return elbo


    def _m_step(self):
        """Performs the gradient update for the hyperparameters (M-Step)."""
        self.optimizer.zero_grad()
        elbo = self._calculate_elbo()
        loss = -elbo # We maximize ELBO, so we minimize -ELBO
        loss.backward()
        self.optimizer.step()
        return elbo.item()

    def fit(self, em_iterations=50, cavi_per_step=10):
        """
        Runs the full Variational EM algorithm.
        """
        print("Starting Variational EM optimization...")
        for i in range(em_iterations):
            # E-Step: Update variational parameters
            self._e_step(cavi_iterations=cavi_per_step)
            
            # M-Step: Update hyperparameters
            elbo = self._m_step()
            
            print(f"EM Iteration {i+1}/{em_iterations}, ELBO: {elbo:.4f}")
        
        print("\nOptimization finished.")
        final_params = self._get_hyperparams()
        print("Final Hyperparameters:")
        for name, val in final_params.items():
            print(f"  {name}: {val.item():.4f}")


if __name__ == '__main__':
    N_train = 100
    X_train = torch.linspace(-5, 5, N_train).unsqueeze(1)
    y_true = torch.sin(X_train)
    y_train = y_true + torch.randn(N_train, 1) * 0.2
    y_train[[10, 20, 80]] += torch.tensor([5.0, -4.0, 6.0]).unsqueeze(1) # Add outliers

    model = TPRegressionVariationalEM(X_train, y_train, M=20)
    model.fit(em_iterations=50, cavi_per_step=5)
# Out:
# Starting Variational EM optimization...
# Warning: precision_u became non-positive definite in E-step. Skipping q(u) update.
# Warning: precision_u became non-positive definite in E-step. Skipping q(u) update.
# Warning: precision_u became non-positive definite in E-step. Skipping q(u) update.
# Warning: precision_u became non-positive definite in E-step. Skipping q(u) update.
# params: nu_f=5.0000, nu_epsilon=5.0000, lengthscale=1.0000, variance=1.0000, sigma_sq=1.0000
# Error: precision_u is not positive definite. ELBO will be nan.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 261
#     258 y_train[[10, 20, 80]] += torch.tensor([5.0, -4.0, 6.0]).unsqueeze(1) # Add outliers
#     260 model = TPRegressionVariationalEM(X_train, y_train, M=20)
# --> 261 model.fit(em_iterations=50, cavi_per_step=5)
#
# Cell In[20], line 242, in TPRegressionVariationalEM.fit(self, em_iterations, cavi_per_step)
#     239     self._e_step(cavi_iterations=cavi_per_step)
#     241     # M-Step: Update hyperparameters
# --> 242     elbo = self._m_step()
#     244     print(f"EM Iteration {i+1}/{em_iterations}, ELBO: {elbo:.4f}")
#     246 print("\nOptimization finished.")
#
# Cell In[20], line 228, in TPRegressionVariationalEM._m_step(self)
#     226 elbo = self._calculate_elbo()
#     227 loss = -elbo # We maximize ELBO, so we minimize -ELBO
# --> 228 loss.backward()
#     229 self.optimizer.step()
#     230 return elbo.item()
#
# File ~/ws/tprt/.venv-tprt/lib/python3.11/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)    646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/ws/tprt/.venv-tprt/lib/python3.11/site-packages/torch/autograd/__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File ~/ws/tprt/.venv-tprt/lib/python3.11/site-packages/torch/autograd/graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
import torch
import torch.optim as optim
import matplotlib.pyplot as plt
from scipy.stats import t
import math

def rbf_kernel(X1, X2, lengthscale=1.0, variance=1.0):
    """
    Computes the RBF kernel matrix between two sets of points.
    """
    # Ensure lengthscale and variance are tensors for autograd
    lengthscale = torch.as_tensor(lengthscale, dtype=X1.dtype, device=X1.device)
    variance = torch.as_tensor(variance, dtype=X1.dtype, device=X1.device)
    
    sqdist = torch.cdist(X1, X2, p=2).pow(2)
    return variance * torch.exp(-0.5 * sqdist / lengthscale**2)

class TPRegression:
    """
    Implementation of Variational EM for Student-t Process Regression.
    - E-Step: CAVI updates for variational parameters.
    - M-Step: Gradient-based optimization of model hyperparameters and inducing points.
    """
    def __init__(self, X, y, Z_initial, nu_f=5.0, nu_e=5.0, kernel_lengthscale=1.0, kernel_variance=1.0, likelihood_sigma=1.0):
        self.X = X
        self.y = y.squeeze()
        self.N, self.D = X.shape
        self.M = Z_initial.shape[0]

        # --- Initialize Hyperparameters and Inducing Points (M-step) ---
        # These are now learnable parameters. We optimize their log for stability.
        self.log_nu_f = torch.nn.Parameter(torch.log(torch.tensor(nu_f)))
        self.log_nu_epsilon = torch.nn.Parameter(torch.log(torch.tensor(nu_e)))
        self.log_sigma_sq = torch.nn.Parameter(torch.log(torch.tensor(likelihood_sigma**2)))
        self.log_kernel_lengthscale = torch.nn.Parameter(torch.log(torch.tensor(kernel_lengthscale)))
        self.log_kernel_variance = torch.nn.Parameter(torch.log(torch.tensor(kernel_variance)))
        self.Z = torch.nn.Parameter(Z_initial.clone())

        # --- Initialize Variational Parameters (E-step) ---
        self.m_u = torch.zeros(self.M, 1)
        self.S_u = torch.eye(self.M)
        self.alpha_r = torch.tensor(1.0)
        self.beta_r = torch.tensor(1.0)
        self.alpha_lambda = torch.ones(self.N)
        self.beta_lambda = torch.ones(self.N)
        
    def _get_hyperparams(self):
        """Returns the exponentiated (positive) hyperparameters."""
        return {
            "nu_f": torch.exp(self.log_nu_f),
            "nu_epsilon": torch.exp(self.log_nu_epsilon),
            "sigma_sq": torch.exp(self.log_sigma_sq),
            "lengthscale": torch.exp(self.log_kernel_lengthscale),
            "variance": torch.exp(self.log_kernel_variance)
        }
        
    def _e_step(self, cavi_max_iter=1):
        """Performs the CAVI updates for the variational parameters (E-Step)."""
        with torch.no_grad(): # No gradients needed for the E-step updates
            params = self._get_hyperparams()
            K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
            K_ZZ_inv = torch.inverse(K_ZZ)
            K_XZ = rbf_kernel(self.X, self.Z, params['lengthscale'], params['variance'])
            
            for _ in range(cavi_max_iter):
                # Update q(lambda)
                K_ZZ_inv_m_u = torch.linalg.solve(K_ZZ, self.m_u)
                expected_f_mean = K_XZ @ K_ZZ_inv_m_u
                if self.alpha_r > 1: expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
                else: expected_r_inv = self.beta_r
                k_ii = torch.diag(rbf_kernel(self.X, self.X, params['lengthscale'], params['variance']))
                K_XZ_K_ZZ_inv = K_XZ @ K_ZZ_inv
                var_f_term1 = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * K_XZ).sum(dim=1))
                var_f_term2 = (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
                var_f = var_f_term1 + var_f_term2
                expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f
                self.alpha_lambda = params['nu_epsilon'] / 2.0 + 0.5
                self.beta_lambda = params['nu_epsilon'] / 2.0 + (0.5 / params['sigma_sq']) * expected_sq_error

                # Update q(r)
                trace_term = torch.trace(K_ZZ_inv @ self.S_u)
                mean_term = self.m_u.T @ K_ZZ_inv @ self.m_u
                expected_u_quadratic_form = trace_term + mean_term
                self.alpha_r = params['nu_f'] / 2.0 + self.M / 2.0
                self.beta_r = params['nu_f'] / 2.0 + 0.5 * expected_u_quadratic_form.squeeze()

                # Update q(u)
                expected_r = self.alpha_r / self.beta_r
                expected_lambda = self.alpha_lambda / self.beta_lambda
                precision_u_prior = expected_r * K_ZZ_inv
                K_ZX = K_XZ.T
                A = K_ZX * (expected_lambda / params['sigma_sq'])
                B = A @ K_XZ
                precision_u_lik = K_ZZ_inv.T @ B @ K_ZZ_inv
                precision_u = precision_u_prior + precision_u_lik
                self.S_u = torch.inverse(precision_u + torch.eye(self.M) * 1e-6)
                b = K_ZZ_inv.T @ (K_ZX @ (expected_lambda * self.y / params['sigma_sq']))
                self.m_u = (self.S_u @ b).unsqueeze(1)

    def _calculate_elbo(self):
        """Calculates the Evidence Lower Bound (ELBO) for the M-step."""
        params = self._get_hyperparams()
        
        K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
        K_ZZ_inv = torch.inverse(K_ZZ)
        K_XZ = rbf_kernel(self.X, self.Z, params['lengthscale'], params['variance'])
        k_ii = torch.diag(rbf_kernel(self.X, self.X, params['lengthscale'], params['variance']))

        # 1. Expected Log-Likelihood
        expected_log_lambda = torch.digamma(self.alpha_lambda) - torch.log(self.beta_lambda)
        expected_lambda = self.alpha_lambda / self.beta_lambda
        K_ZZ_inv_m_u = torch.linalg.solve(K_ZZ, self.m_u)
        expected_f_mean = K_XZ @ K_ZZ_inv_m_u
        if self.alpha_r > 1: expected_r_inv = self.beta_r / (self.alpha_r - 1.0)
        else: expected_r_inv = self.beta_r
        K_XZ_K_ZZ_inv = K_XZ @ K_ZZ_inv
        var_f = expected_r_inv * (k_ii - (K_XZ_K_ZZ_inv * K_XZ).sum(dim=1)) + \
                (K_XZ_K_ZZ_inv @ self.S_u * K_XZ_K_ZZ_inv).sum(dim=1)
        expected_sq_error = (self.y - expected_f_mean.squeeze()).pow(2) + var_f
        
        log_lik = 0.5 * torch.sum(expected_log_lambda - math.log(2 * math.pi) - torch.log(params['sigma_sq']) - \
                                  expected_lambda / params['sigma_sq'] * expected_sq_error)

        # 2. KL Divergences
        p_alpha_r, p_beta_r = params['nu_f'] / 2.0, params['nu_f'] / 2.0
        kl_r = (self.alpha_r - p_alpha_r) * torch.digamma(self.alpha_r) - torch.lgamma(self.alpha_r) + torch.lgamma(p_alpha_r) + \
               p_alpha_r * (torch.log(self.beta_r) - torch.log(p_beta_r)) + self.alpha_r * (p_beta_r - self.beta_r) / self.beta_r
        
        expected_log_r = torch.digamma(self.alpha_r) - torch.log(self.beta_r)
        kl_u = 0.5 * (
            -torch.logdet(self.S_u) - self.M * expected_log_r + torch.logdet(K_ZZ) + \
            (self.alpha_r / self.beta_r) * (torch.trace(K_ZZ_inv @ self.S_u) + self.m_u.T @ K_ZZ_inv @ self.m_u) - self.M
        ).squeeze()
        
        # CORRECTED a typo here: params['nu_e'] -> params['nu_epsilon']
        p_alpha_lambda, p_beta_lambda = params['nu_epsilon'] / 2.0, params['nu_epsilon'] / 2.0
        kl_lambda = torch.sum((self.alpha_lambda - p_alpha_lambda) * torch.digamma(self.alpha_lambda) - \
                    torch.lgamma(self.alpha_lambda) + torch.lgamma(p_alpha_lambda) + \
                    p_alpha_lambda * (torch.log(self.beta_lambda) - torch.log(p_beta_lambda)) + \
                    self.alpha_lambda * (p_beta_lambda - self.beta_lambda) / self.beta_lambda)

        return log_lik - kl_u - kl_r - kl_lambda

    def _m_step(self, optimizer):
        """Performs the gradient update for the hyperparameters (M-Step)."""
        optimizer.zero_grad()
        elbo = self._calculate_elbo()
        loss = -elbo # Maximize ELBO by minimizing -ELBO
        loss.backward()
        optimizer.step()
        return elbo.item()

    def fit(self, max_iter_global=100, cavi_max_iter=10, lr=0.01):
        """Runs the full Variational EM algorithm."""
        optimizer = optim.Adam(
            [self.log_nu_f, self.log_nu_epsilon, self.log_sigma_sq,
             self.log_kernel_lengthscale, self.log_kernel_variance, self.Z],
            lr=lr
        )
        
        elbo_history = []
        print("Starting Variational EM optimization...")
        for i in range(max_iter_global):
            self._e_step(cavi_max_iter=cavi_max_iter)
            elbo = self._m_step(optimizer)
            elbo_history.append(elbo)
            
            if (i + 1) % 50 == 0:
                print(f"EM Iteration {i+1}/{max_iter_global}, ELBO: {elbo:.4f}")
        
        print("\nOptimization finished.")
        return elbo_history

    def predict(self, X_test):
        """
        Makes predictions for new data X_test.
        Returns the parameters of the predictive Student-t distribution.
        """
        with torch.no_grad():
            params = self._get_hyperparams()
            
            K_ZZ = rbf_kernel(self.Z, self.Z, params['lengthscale'], params['variance']) + torch.eye(self.M) * 1e-6
            K_ZZ_inv = torch.inverse(K_ZZ)
            K_star_Z = rbf_kernel(X_test, self.Z, params['lengthscale'], params['variance'])
            k_star_star = torch.diag(rbf_kernel(X_test, X_test, params['lengthscale'], params['variance']))

            K_ZZ_inv_m_u = torch.linalg.solve(K_ZZ, self.m_u)
            pred_mean = (K_star_Z @ K_ZZ_inv_m_u).squeeze()

            K_star_Z_K_ZZ_inv = K_star_Z @ K_ZZ_inv
            gp_var = k_star_star - (K_star_Z_K_ZZ_inv * K_star_Z).sum(dim=1) + \
                     (K_star_Z_K_ZZ_inv @ self.S_u * K_star_Z_K_ZZ_inv).sum(dim=1)
            
            pred_nu = 2 * self.alpha_r
            pred_scale_sq = gp_var * (self.beta_r / self.alpha_r)
            
            return pred_mean, pred_scale_sq, pred_nu

if __name__ == '__main__':
    # 1. Generate data
    N = 100
    X_train = torch.linspace(-5, 5, N).unsqueeze(1)
    y_true = torch.sin(X_train) * 2
    noise = torch.randn(N, 1) * 0.1
    t_dist_sample = torch.distributions.StudentT(df=2)
    outlier_noise = t_dist_sample.sample((N, 1)) * 0.5
    y_train = y_true + noise
    outlier_indices = torch.randperm(N)[:10]
    y_train[outlier_indices] += outlier_noise[outlier_indices] * 3
    y_train[30] = -4.0
    y_train[70] = 5.0

    # 2. Setup the model with INITIAL inducing points
    M = 20
    Z_initial = torch.linspace(-5, 5, M).unsqueeze(1)

    model = TPRegression(
        X=X_train,
        y=y_train,
        Z_initial=Z_initial,
        nu_f=5.0,
        nu_e=5.0,
        kernel_lengthscale=0.5,
        kernel_variance=2.0,
        likelihood_sigma=0.5
    )

    # 3. Fit the model and get ELBO history
    elbo_history = model.fit(max_iter_global=2000, cavi_max_iter=5, lr=0.01)

    # Print final Z locations
    print("\n--- Initial Z ---")
    print(Z_initial.squeeze().numpy())
    print("\n--- Optimized Z ---")
    print(model.Z.detach().squeeze().numpy())
    print("-------------------")

    # 4. Make predictions
    X_test = torch.linspace(-6, 6, 200).unsqueeze(1)
    pred_mean, pred_var, pred_nu = model.predict(X_test)

    # 5. Visualize the regression results
    plt.figure(figsize=(12, 8))

    pred_scale = torch.sqrt(pred_var.clamp(min=1e-9))
    df = pred_nu.item()
    lower_quantile = t.ppf(0.025, df=df)
    upper_quantile = t.ppf(0.975, df=df)
    lower = pred_mean + lower_quantile * pred_scale
    upper = pred_mean + upper_quantile * pred_scale

    plt.fill_between(X_test.squeeze(), lower.squeeze(), upper.squeeze(), color='orange', alpha=0.3, label='95% Predictive Interval (Student-t)')
    plt.plot(X_test, pred_mean, 'r-', lw=2, label='Predictive Mean')
    plt.plot(X_train, y_train, 'kx', mew=2, label='Training Data (with outliers)')
    plt.plot(model.Z.detach(), torch.full_like(model.Z.detach(), -5.5), 'r|', ms=20, mew=2, label='Optimized Inducing Points')

    plt.title('Sparse TP Regression (with Z and Hyperparameter Optimization)', fontsize=16)
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.xlim(-6, 6)
    plt.ylim(-6, 6)
    
    # 6. Visualize ELBO history
    plt.figure(figsize=(12, 6))
    plt.plot(range(1, len(elbo_history) + 1), elbo_history, marker='.', linestyle='-')
    plt.title('Sparse TP ELBO Convergence', fontsize=16)
    plt.xlabel('Iteration', fontsize=12)
    plt.ylabel('ELBO', fontsize=12)
    plt.grid(True)
    plt.tight_layout()

    plt.show()
# Out:
# Starting Variational EM optimization...
# EM Iteration 50/2000, ELBO: -92.1268
# EM Iteration 100/2000, ELBO: nan
# EM Iteration 150/2000, ELBO: nan
# EM Iteration 200/2000, ELBO: nan
# EM Iteration 250/2000, ELBO: nan
# EM Iteration 300/2000, ELBO: nan
# EM Iteration 350/2000, ELBO: nan
# EM Iteration 400/2000, ELBO: nan
# EM Iteration 450/2000, ELBO: nan
# EM Iteration 500/2000, ELBO: nan
# EM Iteration 550/2000, ELBO: nan
# EM Iteration 600/2000, ELBO: nan
# EM Iteration 650/2000, ELBO: nan
# EM Iteration 700/2000, ELBO: nan
# EM Iteration 750/2000, ELBO: nan
# EM Iteration 800/2000, ELBO: nan
# EM Iteration 850/2000, ELBO: nan
# EM Iteration 900/2000, ELBO: nan
# EM Iteration 950/2000, ELBO: nan
# EM Iteration 1000/2000, ELBO: nan
# EM Iteration 1050/2000, ELBO: nan
# EM Iteration 1100/2000, ELBO: nan
# EM Iteration 1150/2000, ELBO: nan
# EM Iteration 1200/2000, ELBO: nan
# EM Iteration 1250/2000, ELBO: nan
# EM Iteration 1300/2000, ELBO: nan
# EM Iteration 1350/2000, ELBO: nan
# EM Iteration 1400/2000, ELBO: nan
# EM Iteration 1450/2000, ELBO: nan
# EM Iteration 1500/2000, ELBO: nan
# EM Iteration 1550/2000, ELBO: nan
# EM Iteration 1600/2000, ELBO: nan
# EM Iteration 1650/2000, ELBO: nan
# EM Iteration 1700/2000, ELBO: nan
# EM Iteration 1750/2000, ELBO: nan
# EM Iteration 1800/2000, ELBO: nan
# EM Iteration 1850/2000, ELBO: nan
# EM Iteration 1900/2000, ELBO: nan
# EM Iteration 1950/2000, ELBO: nan
# EM Iteration 2000/2000, ELBO: nan
#
# Optimization finished.
#
# --- Initial Z ---
# [-5.         -4.4736843  -3.9473684  -3.4210525  -2.8947368  -2.368421
#  -1.8421052  -1.3157893  -0.78947353 -0.26315773  0.26315773  0.78947353
#   1.3157893   1.8421052   2.368421    2.8947368   3.4210525   3.9473684
#   4.4736843   5.        ]
#
# --- Optimized Z ---
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan]
# -------------------

# %%
import torch
import torch.nn as nn
import math
import matplotlib.pyplot as plt
from scipy.stats import t
import tqdm

# Set default tensor type for better performance
torch.set_default_dtype(torch.float64)

class NonSparseTPRegression(nn.Module):
    """
    Implements the full (non-sparse) Student-t Process regression model.
    This model works directly with the N x N kernel matrix and is suitable
    for smaller datasets due to its O(N^3) complexity.
    """
    def __init__(self, X, y, nu_f=3.0, nu_e=3.0,
                 kernel_lengthscale=1.0, kernel_variance=1.0, likelihood_sigma=0.1):
        super().__init__()

        # Data is not a parameter, so register as buffer
        self.register_buffer('X', X)
        self.register_buffer('y', y)

        self.N, self.D = X.shape

        # --- Hyperparameters as nn.Parameter for optimization ---
        self.log_kernel_lengthscale = nn.Parameter(torch.log(torch.tensor(kernel_lengthscale)))
        self.log_kernel_variance = nn.Parameter(torch.log(torch.tensor(kernel_variance)))
        self.log_likelihood_sigma_sq = nn.Parameter(torch.log(torch.tensor(likelihood_sigma**2)))
        self.log_nu_f = nn.Parameter(torch.log(torch.tensor(nu_f)))
        self.log_nu_e = nn.Parameter(torch.log(torch.tensor(nu_e)))

        # --- Variational Parameters ---
        # These are updated via CAVI, not gradient descent, so they are not nn.Parameters.
        # q(f) = N(f | m_f, S_f), where S_f = L_f @ L_f.T
        self.m_f = torch.zeros(self.N, 1)
        self.L_f = torch.eye(self.N)

        # q(r) = Gamma(r | alpha_r, beta_r)
        self.alpha_r = torch.tensor(1.0)
        self.beta_r = torch.tensor(1.0)

        # q(lambda_i) = Gamma(lambda_i | alpha_lambda_i, beta_lambda_i)
        self.alpha_lambda = torch.ones(self.N, 1)
        self.beta_lambda = torch.ones(self.N, 1)

    def _get_hyperparams(self):
        """Helper to get positive hyperparameters from their log-transformed storage."""
        lengthscale = torch.exp(self.log_kernel_lengthscale)
        variance = torch.exp(self.log_kernel_variance)
        sigma_sq = torch.exp(self.log_likelihood_sigma_sq)
        nu_f = torch.exp(self.log_nu_f)
        nu_e = torch.exp(self.log_nu_e)
        return lengthscale, variance, sigma_sq, nu_f, nu_e

    def kernel(self, A, B):
        """Computes the RBF kernel matrix between A and B."""
        lengthscale, variance, _, _, _ = self._get_hyperparams()
        sq_dist = torch.cdist(A, B, p=2).pow(2)
        return variance * torch.exp(-0.5 * sq_dist / lengthscale.pow(2))

    def _update_q_lambda(self):
        """CAVI update for q(lambda_i)."""
        _, _, sigma_sq, _, nu_e = self._get_hyperparams()
        S_f = self.L_f @ self.L_f.T
        Var_q_f = S_f.diag().unsqueeze(1)
        E_q_f = self.m_f

        self.alpha_lambda = nu_e / 2.0 + 0.5
        expected_sq_error = (self.y - E_q_f).pow(2) + Var_q_f
        self.beta_lambda = nu_e / 2.0 + (1.0 / (2.0 * sigma_sq)) * expected_sq_error

    def _update_q_r(self, Lxx):
        """CAVI update for q(r)."""
        _, _, _, nu_f, _ = self._get_hyperparams()
        S_f = self.L_f @ self.L_f.T

        # E[f^T Kxx^-1 f] = Tr(Kxx^-1 S_f) + m_f^T Kxx^-1 m_f
        Kxx_inv_Sf = torch.cholesky_solve(S_f, Lxx)
        trace_term = torch.trace(Kxx_inv_Sf)
        Kxx_inv_mf = torch.cholesky_solve(self.m_f, Lxx)
        quad_form_term = self.m_f.T @ Kxx_inv_mf
        E_quad_form_f = trace_term + quad_form_term

        self.alpha_r = nu_f / 2.0 + self.N / 2.0
        self.beta_r = nu_f / 2.0 + 0.5 * E_quad_form_f.squeeze()

    def _update_q_f(self, Kxx, Lxx):
        """CAVI update for q(f)."""
        _, _, sigma_sq, _, _ = self._get_hyperparams()
        E_r = self.alpha_r / self.beta_r
        E_lambda = self.alpha_lambda / self.beta_lambda

        # S_f^-1 = E[r] * Kxx^-1 + diag(E[lambda]/sigma^2)
        Kxx_inv = torch.cholesky_inverse(Lxx)
        S_f_inv = E_r * Kxx_inv + torch.diag(E_lambda.squeeze() / sigma_sq)
        
        # S_f = S_f_inv^-1
        L_f_inv = torch.linalg.cholesky(S_f_inv)
        self.L_f = torch.triangular_solve(torch.eye(self.N), L_f_inv, upper=False)[0]

        # m_f = S_f @ (diag(E[lambda]/sigma^2) @ y)
        temp_vec = (E_lambda / sigma_sq) * self.y
        self.m_f = torch.cholesky_solve(temp_vec, L_f_inv)

    def _cavi_step(self, Kxx, Lxx, cavi_max_iter=10, cavi_tol=1e-5):
        """Runs the inner CAVI loop until convergence for fixed hyperparameters."""
        for _ in range(cavi_max_iter):
            m_f_old = self.m_f.clone()

            # CAVI updates
            self._update_q_lambda()
            self._update_q_r(Lxx)
            self._update_q_f(Kxx, Lxx)

            # Check for convergence
            change = torch.norm(self.m_f - m_f_old) / (torch.norm(m_f_old) + 1e-9)
            if change < cavi_tol:
                break

    def calculate_elbo(self, Kxx, Lxx):
        """Calculates the Evidence Lower Bound (ELBO) for the current model state."""
        _, _, sigma_sq, nu_f, nu_e = self._get_hyperparams()
        S_f = self.L_f @ self.L_f.T
        Var_q_f = S_f.diag().unsqueeze(1)

        # --- 1. Expected Log Likelihood ---
        E_q_f = self.m_f
        expected_sq_error = (self.y - E_q_f).pow(2) + Var_q_f

        E_lambda = self.alpha_lambda / self.beta_lambda
        E_log_lambda = torch.digamma(self.alpha_lambda) - torch.log(self.beta_lambda)

        e_log_lik = -0.5 * self.N * torch.log(torch.tensor(2 * torch.pi)) - 0.5 * self.N * torch.log(sigma_sq) + \
                    0.5 * torch.sum(E_log_lambda) - \
                    0.5 / sigma_sq * torch.sum(E_lambda * expected_sq_error)

        # --- 2. KL Divergence for f and r ---
        E_r = self.alpha_r / self.beta_r
        E_log_r = torch.digamma(self.alpha_r) - torch.log(self.beta_r)

        # log q(f)
        log_q_f = -0.5 * self.N * torch.log(torch.tensor(2 * torch.pi)) - torch.sum(torch.log(torch.diag(self.L_f))) - 0.5 * self.N
        
        # log q(r)
        log_q_r = self.alpha_r * torch.log(self.beta_r) - torch.lgamma(self.alpha_r) + \
                  (self.alpha_r - 1) * E_log_r - self.beta_r * E_r

        # E[log p(f|r)]
        Kxx_inv_Sf = torch.cholesky_solve(S_f, Lxx)
        trace_term = torch.trace(Kxx_inv_Sf)
        Kxx_inv_mf = torch.cholesky_solve(self.m_f, Lxx)
        quad_form_term = self.m_f.T @ Kxx_inv_mf
        E_quad_form_f = trace_term + quad_form_term

        log_det_Kxx = 2 * torch.sum(torch.log(torch.diag(Lxx)))
        E_log_p_f_r = -0.5 * self.N * torch.log(torch.tensor(2 * torch.pi)) - 0.5 * log_det_Kxx + \
                      0.5 * self.N * E_log_r - 0.5 * E_r * E_quad_form_f

        # E[log p(r)]
        E_log_p_r = (nu_f / 2) * torch.log(nu_f / 2) - torch.lgamma(nu_f / 2) + \
                    (nu_f / 2 - 1) * E_log_r - (nu_f / 2) * E_r

        kl_f_r = log_q_f + log_q_r - E_log_p_f_r - E_log_p_r

        # --- 3. KL Divergence for lambda_i ---
        kl_lambda = torch.lgamma(self.alpha_lambda) - self.alpha_lambda * torch.log(self.beta_lambda) - \
                    (torch.lgamma(nu_e / 2) - (nu_e / 2) * torch.log(nu_e / 2)) - \
                    (self.alpha_lambda - nu_e / 2) * E_log_lambda + \
                    (self.beta_lambda - nu_e / 2) * E_lambda

        kl_lambda_sum = torch.sum(kl_lambda)

        elbo = e_log_lik - kl_f_r - kl_lambda_sum
        return elbo

    def fit(self, max_iter_global=100, max_iter_local=10, lr=0.01, cavi_max_iter=10, cavi_tol=1e-5):
        """
        Fits the model by alternating between CAVI updates (E-step) and
        gradient-based hyperparameter updates (M-step).
        """
        print("Starting optimization for non-sparse model...")
        pbar = tqdm.trange(max_iter_global)

        for i in pbar:
            # Recompute Kxx and its Cholesky factor in each loop as hyperparameters change
            Kxx = self.kernel(self.X, self.X) + torch.eye(self.N) * 1e-6
            Lxx = torch.linalg.cholesky(Kxx)

            # E-Step: Run CAVI to update variational parameters for q(f), q(r), q(lambda)
            with torch.no_grad():
                self._cavi_step(Kxx, Lxx, cavi_max_iter, cavi_tol)

            # M-Step: Update hyperparameters by maximizing the ELBO
            optimizer = torch.optim.Adam(self.parameters(), lr=lr)

            for j in range(max_iter_local):
                optimizer.zero_grad()
                Kxx = self.kernel(self.X, self.X) + torch.eye(self.N) * 1e-6
                Lxx = torch.linalg.cholesky(Kxx)
                neg_elbo = -self.calculate_elbo(Kxx, Lxx)
                neg_elbo.backward()
                optimizer.step()

            pbar.set_description(f"ELBO: {-neg_elbo.item():.2f}")

    def predict(self, X_test):
        """Make predictions at new test points X_test."""
        with torch.no_grad():
            K_star_x = self.kernel(X_test, self.X)
            K_star_star_diag = self.kernel(X_test, X_test).diag()
            Kxx = self.kernel(self.X, self.X) + torch.eye(self.N) * 1e-6
            Lxx = torch.linalg.cholesky(Kxx)

            # Predictive Mean: E[f_*] = k(X_*, X) K(X,X)^-1 m_f
            Kxx_inv_mf = torch.cholesky_solve(self.m_f, Lxx)
            pred_mean = K_star_x @ Kxx_inv_mf

            # --- CORRECTED Predictive Variance Calculation ---
            S_f = self.L_f @ self.L_f.T
            Kxx_inv_k_x_star = torch.cholesky_solve(K_star_x.T, Lxx)
            
            # Term 1: Var[E[f_*|f]] = k_*x Kxx^-1 S_f Kxx^-1 k_x*
            # This is the corrected part.
            var_from_q_f = (K_star_x @ torch.cholesky_solve(S_f @ Kxx_inv_k_x_star, Lxx)).diag()

            # Term 2: E[Var[f_*|f,r]] = E[r^-1] * (k_** - k_*x Kxx^-1 k_x*)
            E_inv_r = self.beta_r / (self.alpha_r - 1.0) if self.alpha_r > 1 else self.beta_r
            var_from_prior = E_inv_r * (K_star_star_diag - (K_star_x * Kxx_inv_k_x_star.T).sum(dim=1))

            pred_var = var_from_prior + var_from_q_f
            
            # The predictive distribution is Student-t
            pred_nu = 2 * self.alpha_r

            return pred_mean.detach(), pred_var.unsqueeze(1).detach(), pred_nu.detach()


if __name__ == '__main__':
    # 1. Generate data
    N = 60
    X_train = torch.linspace(-5, 5, N).unsqueeze(1)
    y_true = torch.sin(X_train) * 2
    noise = torch.randn(N, 1) * 0.1
    t_dist_sample = torch.distributions.StudentT(df=2)
    outlier_noise = t_dist_sample.sample((N, 1)) * 0.5
    y_train = y_true + noise
    
    # Add some significant outliers
    outlier_indices = torch.randperm(N)[:8]
    y_train[outlier_indices] += outlier_noise[outlier_indices] * 3
    y_train[15] = -4.0
    y_train[45] = 5.0

    # 2. Setup the non-sparse model
    model = NonSparseTPRegression(
        X=X_train,
        y=y_train,
        nu_f=2.1,
        nu_e=2.1,
        kernel_lengthscale=0.5,
        kernel_variance=2.0,
        likelihood_sigma=5
    )

    # 3. Fit the model
    model.fit(max_iter_global=100, max_iter_local=10, lr=0.05, cavi_max_iter=20)

    # 4. Make predictions
    X_test = torch.linspace(-6, 6, 200).unsqueeze(1)
    pred_mean, pred_var, pred_nu = model.predict(X_test)

    # 5. Visualize the results
    plt.figure(figsize=(12, 8))

    pred_scale = torch.sqrt(pred_var.clamp(min=1e-9)) # Add clamp for stability
    df = pred_nu.item()
    lower_quantile = t.ppf(0.025, df=df)
    upper_quantile = t.ppf(0.975, df=df)
    
    lower = pred_mean + lower_quantile * pred_scale
    upper = pred_mean + upper_quantile * pred_scale

    plt.fill_between(X_test.squeeze(), lower.squeeze(), upper.squeeze(), color='orange', alpha=0.3, label='95% Predictive Interval (Student-t)')
    plt.plot(X_test, pred_mean, 'r-', lw=2, label='Predictive Mean')
    plt.plot(X_train, y_train, 'kx', mew=2, label='Training Data (with outliers)')

    plt.title('Non-Sparse TP Regression (with Hyperparameter Optimization - Corrected)', fontsize=16)
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.xlim(-6, 6)
    plt.ylim(-6, 6)
    
    plt.show()
# Out:
# Starting optimization for non-sparse model...
# ELBO: 2838.81: 100%|██████████| 100/100 [00:02<00:00, 33.79it/s]

# %%
# Out:
# Starting CAVI optimization...
# Iteration 1/100, Change in m_u: 7094752002.066818
# Iteration 2/100, Change in m_u: 0.141752
# Iteration 3/100, Change in m_u: 0.060889
# Iteration 4/100, Change in m_u: 0.032519
# Iteration 5/100, Change in m_u: 0.021575
# Iteration 6/100, Change in m_u: 0.018821
# Iteration 7/100, Change in m_u: 0.017212
# Iteration 8/100, Change in m_u: 0.014913
# Iteration 9/100, Change in m_u: 0.011933
# Iteration 10/100, Change in m_u: 0.008901
# Iteration 11/100, Change in m_u: 0.006199
# Iteration 12/100, Change in m_u: 0.004055
# Iteration 13/100, Change in m_u: 0.002525
# Iteration 14/100, Change in m_u: 0.001518
# Iteration 15/100, Change in m_u: 0.000891
# Iteration 16/100, Change in m_u: 0.000515
# Iteration 17/100, Change in m_u: 0.000294
# Iteration 18/100, Change in m_u: 0.000167
# Iteration 19/100, Change in m_u: 0.000094
# Iteration 20/100, Change in m_u: 0.000053
# Iteration 21/100, Change in m_u: 0.000030
# Iteration 22/100, Change in m_u: 0.000017
# Iteration 23/100, Change in m_u: 0.000009
# Iteration 24/100, Change in m_u: 0.000005
# Iteration 25/100, Change in m_u: 0.000003
# Iteration 26/100, Change in m_u: 0.000002
# Iteration 27/100, Change in m_u: 0.000001
# Convergence reached after 27 iterations.
# Optimization finished.

# %%
import torch
import torch.nn as nn
import math
import matplotlib.pyplot as plt
from scipy.stats import t
import tqdm

# Set default tensor type for better performance
torch.set_default_dtype(torch.float64)

class NonSparseTPRegression(nn.Module):
    """
    Implements the full (non-sparse) Student-t Process regression model.
    This model works directly with the N x N kernel matrix and is suitable
    for smaller datasets due to its O(N^3) complexity.
    """
    def __init__(self, X, y, nu_f=3.0, nu_e=3.0,
                 kernel_lengthscale=1.0, kernel_variance=1.0, likelihood_sigma=0.1):
        super().__init__()

        # Data is not a parameter, so register as buffer
        self.register_buffer('X', X)
        self.register_buffer('y', y)

        self.N, self.D = X.shape

        # --- Hyperparameters as nn.Parameter for optimization ---
        self.log_kernel_lengthscale = nn.Parameter(torch.log(torch.tensor(kernel_lengthscale)))
        self.log_kernel_variance = nn.Parameter(torch.log(torch.tensor(kernel_variance)))
        self.log_likelihood_sigma_sq = nn.Parameter(torch.log(torch.tensor(likelihood_sigma**2)))
        self.log_nu_f = nn.Parameter(torch.log(torch.tensor(nu_f)))
        self.log_nu_e = nn.Parameter(torch.log(torch.tensor(nu_e)))

        # --- Variational Parameters ---
        # These are updated via CAVI, not gradient descent, so they are not nn.Parameters.
        # q(f) = N(f | m_f, S_f), where S_f = L_f @ L_f.T
        self.m_f = torch.zeros(self.N, 1)
        self.L_f = torch.eye(self.N)

        # q(r) = Gamma(r | alpha_r, beta_r)
        self.alpha_r = torch.tensor(1.0)
        self.beta_r = torch.tensor(1.0)

        # q(lambda_i) = Gamma(lambda_i | alpha_lambda_i, beta_lambda_i)
        self.alpha_lambda = torch.ones(self.N, 1)
        self.beta_lambda = torch.ones(self.N, 1)

        self.elbo_history = []

    def _get_hyperparams(self):
        """Helper to get positive hyperparameters from their log-transformed storage."""
        lengthscale = torch.exp(self.log_kernel_lengthscale)
        variance = torch.exp(self.log_kernel_variance)
        sigma_sq = torch.exp(self.log_likelihood_sigma_sq)
        nu_f = torch.exp(self.log_nu_f)
        nu_e = torch.exp(self.log_nu_e)
        return lengthscale, variance, sigma_sq, nu_f, nu_e

    def kernel(self, A, B):
        """Computes the RBF kernel matrix between A and B."""
        lengthscale, variance, _, _, _ = self._get_hyperparams()
        sq_dist = torch.cdist(A, B, p=2).pow(2)
        return variance * torch.exp(-0.5 * sq_dist / lengthscale.pow(2))

    def _update_q_lambda(self):
        """CAVI update for q(lambda_i)."""
        _, _, sigma_sq, _, nu_e = self._get_hyperparams()
        S_f = self.L_f @ self.L_f.T
        Var_q_f = S_f.diag().unsqueeze(1)
        E_q_f = self.m_f

        self.alpha_lambda = nu_e / 2.0 + 0.5
        expected_sq_error = (self.y - E_q_f).pow(2) + Var_q_f
        self.beta_lambda = nu_e / 2.0 + (1.0 / (2.0 * sigma_sq)) * expected_sq_error

    def _update_q_r(self, Lxx):
        """CAVI update for q(r)."""
        _, _, _, nu_f, _ = self._get_hyperparams()
        S_f = self.L_f @ self.L_f.T

        # E[f^T Kxx^-1 f] = Tr(Kxx^-1 S_f) + m_f^T Kxx^-1 m_f
        Kxx_inv_Sf = torch.cholesky_solve(S_f, Lxx)
        trace_term = torch.trace(Kxx_inv_Sf)
        Kxx_inv_mf = torch.cholesky_solve(self.m_f, Lxx)
        quad_form_term = self.m_f.T @ Kxx_inv_mf
        E_quad_form_f = trace_term + quad_form_term

        self.alpha_r = nu_f / 2.0 + self.N / 2.0
        self.beta_r = nu_f / 2.0 + 0.5 * E_quad_form_f.squeeze()

    def _update_q_f(self, Kxx, Lxx):
        """CAVI update for q(f)."""
        _, _, sigma_sq, _, _ = self._get_hyperparams()
        E_r = self.alpha_r / self.beta_r
        E_lambda = self.alpha_lambda / self.beta_lambda

        # S_f^-1 = E[r] * Kxx^-1 + diag(E[lambda]/sigma^2)
        Kxx_inv = torch.cholesky_inverse(Lxx)
        S_f_inv = E_r * Kxx_inv + torch.diag(E_lambda.squeeze() / sigma_sq)
        
        # S_f = S_f_inv^-1
        L_f_inv = torch.linalg.cholesky(S_f_inv)
        self.L_f = torch.triangular_solve(torch.eye(self.N), L_f_inv, upper=False)[0]

        # m_f = S_f @ (diag(E[lambda]/sigma^2) @ y)
        temp_vec = (E_lambda / sigma_sq) * self.y
        self.m_f = torch.cholesky_solve(temp_vec, L_f_inv)

    def _cavi_step(self, Kxx, Lxx, cavi_max_iter=10, cavi_tol=1e-5):
        """Runs the inner CAVI loop until convergence for fixed hyperparameters."""
        for _ in range(cavi_max_iter):
            m_f_old = self.m_f.clone()

            # CAVI updates
            self._update_q_lambda()
            self._update_q_r(Lxx)
            self._update_q_f(Kxx, Lxx)

            self.elbo_history.append(self.calculate_elbo(Kxx, Lxx))

            # Check for convergence
            change = torch.norm(self.m_f - m_f_old) / (torch.norm(m_f_old) + 1e-9)
            if change < cavi_tol:
                break

    def calculate_elbo(self, Kxx, Lxx):
        """Calculates the Evidence Lower Bound (ELBO) for the current model state."""
        _, _, sigma_sq, nu_f, nu_e = self._get_hyperparams()
        S_f = self.L_f @ self.L_f.T
        Var_q_f = S_f.diag().unsqueeze(1)

        # --- 1. Expected Log Likelihood ---
        E_q_f = self.m_f
        expected_sq_error = (self.y - E_q_f).pow(2) + Var_q_f

        E_lambda = self.alpha_lambda / self.beta_lambda
        E_log_lambda = torch.digamma(self.alpha_lambda) - torch.log(self.beta_lambda)

        e_log_lik = -0.5 * self.N * torch.log(torch.tensor(2 * torch.pi)) - 0.5 * self.N * torch.log(sigma_sq) + \
                    0.5 * torch.sum(E_log_lambda) - \
                    0.5 / sigma_sq * torch.sum(E_lambda * expected_sq_error)

        # --- 2. KL Divergence for f and r ---
        E_r = self.alpha_r / self.beta_r
        E_log_r = torch.digamma(self.alpha_r) - torch.log(self.beta_r)

        # log q(f)
        log_q_f = -0.5 * self.N * torch.log(torch.tensor(2 * torch.pi)) - torch.sum(torch.log(torch.diag(self.L_f))) - 0.5 * self.N
        
        # log q(r)
        log_q_r = self.alpha_r * torch.log(self.beta_r) - torch.lgamma(self.alpha_r) + \
                  (self.alpha_r - 1) * E_log_r - self.beta_r * E_r

        # E[log p(f|r)]
        Kxx_inv_Sf = torch.cholesky_solve(S_f, Lxx)
        trace_term = torch.trace(Kxx_inv_Sf)
        Kxx_inv_mf = torch.cholesky_solve(self.m_f, Lxx)
        quad_form_term = self.m_f.T @ Kxx_inv_mf
        E_quad_form_f = trace_term + quad_form_term

        log_det_Kxx = 2 * torch.sum(torch.log(torch.diag(Lxx)))
        E_log_p_f_r = -0.5 * self.N * torch.log(torch.tensor(2 * torch.pi)) - 0.5 * log_det_Kxx + \
                      0.5 * self.N * E_log_r - 0.5 * E_r * E_quad_form_f

        # E[log p(r)]
        E_log_p_r = (nu_f / 2) * torch.log(nu_f / 2) - torch.lgamma(nu_f / 2) + \
                    (nu_f / 2 - 1) * E_log_r - (nu_f / 2) * E_r

        kl_f_r = log_q_f + log_q_r - E_log_p_f_r - E_log_p_r

        # --- 3. KL Divergence for lambda_i ---
        kl_lambda = torch.lgamma(self.alpha_lambda) - self.alpha_lambda * torch.log(self.beta_lambda) - \
                    (torch.lgamma(nu_e / 2) - (nu_e / 2) * torch.log(nu_e / 2)) - \
                    (self.alpha_lambda - nu_e / 2) * E_log_lambda + \
                    (self.beta_lambda - nu_e / 2) * E_lambda

        kl_lambda_sum = torch.sum(kl_lambda)

        elbo = e_log_lik - kl_f_r - kl_lambda_sum
        return elbo

    def fit(self, max_iter_global=100, max_iter_local=10, lr=0.01, cavi_max_iter=10, cavi_tol=1e-5):
        """
        Fits the model by alternating between CAVI updates (E-step) and
        gradient-based hyperparameter updates (M-step).
        """
        print("Starting optimization for non-sparse model...")
        pbar = tqdm.trange(max_iter_global)

        for i in pbar:
            # Recompute Kxx and its Cholesky factor in each loop as hyperparameters change
            Kxx = self.kernel(self.X, self.X) + torch.eye(self.N) * 1e-6
            Lxx = torch.linalg.cholesky(Kxx)

            # E-Step: Run CAVI to update variational parameters for q(f), q(r), q(lambda)
            with torch.no_grad():
                self._cavi_step(Kxx, Lxx, cavi_max_iter, cavi_tol)

            # M-Step: Update hyperparameters by maximizing the ELBO
            optimizer = torch.optim.Adam(self.parameters(), lr=lr)

            for j in range(max_iter_local):
                optimizer.zero_grad()
                Kxx = self.kernel(self.X, self.X) + torch.eye(self.N) * 1e-6
                Lxx = torch.linalg.cholesky(Kxx)
                neg_elbo = -self.calculate_elbo(Kxx, Lxx)
                neg_elbo.backward()
                optimizer.step()

            pbar.set_description(f"ELBO: {-neg_elbo.item():.2f}")

    def predict(self, X_test):
        """Make predictions at new test points X_test."""
        with torch.no_grad():
            K_star_x = self.kernel(X_test, self.X)
            K_star_star_diag = self.kernel(X_test, X_test).diag()
            Kxx = self.kernel(self.X, self.X) + torch.eye(self.N) * 1e-6
            Lxx = torch.linalg.cholesky(Kxx)

            # Predictive Mean: E[f_*] = k(X_*, X) K(X,X)^-1 m_f
            Kxx_inv_mf = torch.cholesky_solve(self.m_f, Lxx)
            pred_mean = K_star_x @ Kxx_inv_mf

            # --- CORRECTED Predictive Variance Calculation ---
            S_f = self.L_f @ self.L_f.T
            Kxx_inv_k_x_star = torch.cholesky_solve(K_star_x.T, Lxx)
            
            # Term 1: Var[E[f_*|f]] = k_*x Kxx^-1 S_f Kxx^-1 k_x*
            # This is the corrected part.
            var_from_q_f = (K_star_x @ torch.cholesky_solve(S_f @ Kxx_inv_k_x_star, Lxx)).diag()

            # Term 2: E[Var[f_*|f,r]] = E[r^-1] * (k_** - k_*x Kxx^-1 k_x*)
            E_inv_r = self.beta_r / (self.alpha_r - 1.0) if self.alpha_r > 1 else self.beta_r
            var_from_prior = E_inv_r * (K_star_star_diag - (K_star_x * Kxx_inv_k_x_star.T).sum(dim=1))

            pred_var = var_from_prior + var_from_q_f
            
            # The predictive distribution is Student-t
            pred_nu = 2 * self.alpha_r

            return pred_mean.detach(), pred_var.unsqueeze(1).detach(), pred_nu.detach()


if __name__ == '__main__':
    # 1. Generate data
    N = 60
    X_train = torch.linspace(-5, 5, N).unsqueeze(1)
    y_true = torch.sin(X_train) * 2
    noise = torch.randn(N, 1) * 0.1
    t_dist_sample = torch.distributions.StudentT(df=2)
    outlier_noise = t_dist_sample.sample((N, 1)) * 0.5
    y_train = y_true + noise
    
    # Add some significant outliers
    outlier_indices = torch.randperm(N)[:8]
    y_train[outlier_indices] += outlier_noise[outlier_indices] * 3
    y_train[15] = -4.0
    y_train[45] = 5.0

    # 2. Setup the non-sparse model
    model = NonSparseTPRegression(
        X=X_train,
        y=y_train,
        nu_f=2.1,
        nu_e=2.1,
        kernel_lengthscale=0.5,
        kernel_variance=2.0,
        likelihood_sigma=5
    )

    # 3. Fit the model
    model.fit(max_iter_global=1, max_iter_local=1, lr=0.05, cavi_max_iter=1000, cavi_tol=1e-9)

    # 4. Make predictions
    X_test = torch.linspace(-6, 6, 200).unsqueeze(1)
    pred_mean, pred_var, pred_nu = model.predict(X_test)

    # 5. Visualize the results
    plt.figure(figsize=(12, 8))

    pred_scale = torch.sqrt(pred_var.clamp(min=1e-9)) # Add clamp for stability
    df = pred_nu.item()
    lower_quantile = t.ppf(0.025, df=df)
    upper_quantile = t.ppf(0.975, df=df)
    
    lower = pred_mean + lower_quantile * pred_scale
    upper = pred_mean + upper_quantile * pred_scale

    plt.fill_between(X_test.squeeze(), lower.squeeze(), upper.squeeze(), color='orange', alpha=0.3, label='95% Predictive Interval (Student-t)')
    plt.plot(X_test, pred_mean, 'r-', lw=2, label='Predictive Mean')
    plt.plot(X_train, y_train, 'kx', mew=2, label='Training Data (with outliers)')

    plt.title('Non-Sparse TP Regression (with Hyperparameter Optimization - Corrected)', fontsize=16)
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.xlim(-6, 6)
    plt.ylim(-6, 6)
    
    plt.show()
# Out:
# Starting optimization for non-sparse model...
# ELBO: -296.22: 100%|██████████| 1/1 [00:00<00:00, 17.41it/s]

# %%
model.elbo_history
# Out:
# [tensor([[-308.2695]]),
#  tensor([[-303.7967]]),
#  tensor([[-300.1427]]),
#  tensor([[-298.2111]]),
#  tensor([[-297.2473]]),
#  tensor([[-296.7629]]),
#  tensor([[-296.5130]]),
#  tensor([[-296.3807]]),
#  tensor([[-296.3094]]),
#  tensor([[-296.2703]]),
#  tensor([[-296.2488]]),
#  tensor([[-296.2369]]),
#  tensor([[-296.2303]]),
#  tensor([[-296.2266]]),
#  tensor([[-296.2246]]),
#  tensor([[-296.2235]]),
#  tensor([[-296.2228]]),
#  tensor([[-296.2225]]),
#  tensor([[-296.2223]]),
#  tensor([[-296.2222]]),
#  tensor([[-296.2221]]),
#  tensor([[-296.2221]]),
#  tensor([[-296.2221]]),
#  tensor([[-296.2220]]),
#  tensor([[-296.2220]]),
#  tensor([[-296.2220]]),
#  tensor([[-296.2220]]),
#  tensor([[-296.2220]]),
#  tensor([[-296.2220]]),
#  tensor([[-296.2220]]),
#  tensor([[-296.2220]]),
#  tensor([[-296.2220]]),
#  tensor([[-296.2220]])]

# %%
progress_y = torch.tensor(model.elbo_history).squeeze().numpy()
plt.figure(figsize=(12, 6))
plt.plot(range(1, len(progress_y) + 1), progress_y, marker='.', linestyle='-')
plt.title('Non-Sparse TP ELBO Convergence', fontsize=16)
plt.xlabel('Iteration', fontsize=12)
plt.ylabel('ELBO', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()
